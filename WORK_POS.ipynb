# %%
# !pip install sklearn-crfsuite
# !pip install pythainlp
# Out:
# Collecting sklearn-crfsuite
#   Downloading https://files.pythonhosted.org/packages/25/74/5b7befa513482e6dee1f3dd68171a6c9dfc14c0eaa00f885ffeba54fe9b0/sklearn_crfsuite-0.3.6-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite) (4.41.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite) (0.8.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite) (1.15.0)
# Collecting python-crfsuite>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/95/99/869dde6dbf3e0d07a013c8eebfb0a3d30776334e0097f8432b631a9a3a19/python_crfsuite-0.9.7-cp36-cp36m-manylinux1_x86_64.whl (743kB)
#      |████████████████████████████████| 747kB 4.8MB/s
# Installing collected packages: python-crfsuite, sklearn-crfsuite
# Successfully installed python-crfsuite-0.9.7 sklearn-crfsuite-0.3.6
# Collecting pythainlp
#   Downloading https://files.pythonhosted.org/packages/70/eb/777518b11c9abe17b1f04692a079481b8503e186cc59bc32bfc5e4f97fff/pythainlp-2.2.5-py3-none-any.whl (8.9MB)
#      |████████████████████████████████| 8.9MB 4.6MB/s
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.6/dist-packages (from pythainlp) (2.23.0)
# Collecting tinydb>=3.0
#   Downloading https://files.pythonhosted.org/packages/e5/7e/85ee672ee60affd5b4461efa19f260cf7575f36b94fbd1f0825742639910/tinydb-4.3.0-py3-none-any.whl
# Requirement already satisfied: python-crfsuite>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from pythainlp) (0.9.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.22.0->pythainlp) (3.0.4)
# Installing collected packages: tinydb, pythainlp
# Successfully installed pythainlp-2.2.5 tinydb-4.3.0

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4b5fa657-983d-4803-a657-6de5910e165c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b5fa657-983d-4803-a657-6de5910e165c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NAME.txt to NAME.txt

# %%
import codecs
import pickle
from pythainlp.tokenize import word_tokenize
from pythainlp.tag import pos_tag
from pythainlp.tokenize import Tokenizer
from pythainlp.util.trie import Trie, dict_trie
from pythainlp.corpus.common import thai_words
from pythainlp.corpus import thai_stopwords
from nltk.tokenize import RegexpTokenizer
import glob
import nltk
import scipy.stats
import re
from sklearn_crfsuite import scorers,metrics
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_validate,train_test_split
import sklearn_crfsuite
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
file_name="30_data_ok_" # ชื่อไฟล์คลังข้อมูล
def get_data(fileopen):
	"""
    สำหรับใช้อ่านทั้งหมดทั้งในไฟล์ทีละรรทัดออกมาเป็น list
    """
	with codecs.open(fileopen, 'r',encoding='utf-8-sig') as f:
		lines = f.read().splitlines()
	return [a for a in lines if Unique(a)]# เอาไม่ซ้ำกัน

# %% [markdown]
# <h1># จัดการกับ tag ที่ไม่ได้ tag

# %%
def toolner_to_tag(text):
 text=text.strip()
 text=text.replace(" ","")
 text=re.sub("<[^>]*>","",text)
 text=re.sub("(\[\/(.*?)\])","\\1***",text)#.replace('(\[(.*?)\])','***\\1')#  ตัดการกับพวกไม่มี tag word
 text=re.sub("(\[\w+\])","***\\1",text)
 text2=[]
 for i in text.split('***'):
  if "[" in i:
   text2.append(i)
  else:
   text2.append("[word]"+i+"[/word]")
 text="".join(text2)#re.sub("[word][/word]","","".join(text2))
 return text.replace("[word][/word]","")

# %%
#text2conll2002("ดังนั้น[noun]คำสั่งฟ้อง[/noun][Noun Conjunctions]ของ[/Noun Conjunctions][noun]อธิบดี[/noun][noun]อัยการ[/noun][noun]สำนักงานคดีอาญา[/noun][noun]กรุงเทพใต้[/noun][word before verb]จึง[/word before verb][word before verb]ยังคงใช้[/word before verb][intransitive verb]บังคับ[/intransitive verb][word after verb]อยู่[/word after verb][Adverbs]เช่นเดิม[/Adverbs]แต่[Noun phrase]การที่รองอัยการสูงสุด[/Noun phrase]")

# %%
def text2conll2002(text,pos=True):
    """
    ใช้แปลงข้อความให้กลายเป็น conll2002
    """
    text=toolner_to_tag(text) # นำไปใส่ tag [word] "[word]เราจะไปเดินเล่นที่[/word]"
    text=text.replace("''",'"')
    text=text.replace("’",'"').replace("‘",'"')#.replace('"',"")
    tag=tokenizer.tokenize(text) # แยก tag ออกมาจากข้อความ [('word', 'ฉันจะไปเดินเล่นที่', 'word'),('LOCATION', 'หนองคาย', 'LOCATION'),('word', 'พร้อมกับนั่งเรือข้ามไป', 'word'),('LOCATION', 'ประเทศลาว', 'LOCATION')]
    j=0
    conll2002="" # ประกาศตัวแปรเก็บ conll2002
    for tagopen,text,tagclose in tag: # ลูปใน tag โดยเป็น (tagopen,text,tagclose) word_tokenize(text,engine="newmm")
        word_cut=_tokenizer.word_tokenize(text) # ใช้ตัวตัดคำ newmm ของ PyThaiNLP ['ฉัน', 'จะ', 'ไป', 'เดินเล่น', 'ที่']['หนองคาย']['พร้อมกับ', 'นั่ง', 'เรือ', 'ข้าม', 'ไป']['ประเทศ', 'ลาว']
        i=0
        txt5=""
        while i<len(word_cut): #ลูปตามจำนวน token ที่ตัดในtag
            if word_cut[i]=="''" or word_cut[i]=='"':pass
            elif i==0 and tagopen!='word': # ไม่เป็น tag [word] และเป็น i หรือตัวเริ่มต้น tag
                txt5+=word_cut[i]
                txt5+='\t'+''+tagopen
            elif tagopen!='word':
                txt5+=word_cut[i]
                txt5+='\t'+''+tagopen
            else: # เป็น [word]
                txt5+=word_cut[i]
                txt5+='\t'+'O'
            txt5+='\n'
            #j+=1
            i+=1
        conll2002+=txt5
    if pos==False:
        return conll2002
    return postag(conll2002)

# %%
def postag(text):
    listtxt=[i for i in text.split('\n') if i!='']
    list_word=[]
    for data in listtxt:
        list_word.append(data.split('\t')[0])
    #print(text)
    list_word=pos_tag(list_word,engine="perceptron")
    text=""
    i=0
    for data in listtxt:
        text+=data.split('\t')[0]+'\t'+list_word[i][1]+'\t'+data.split('\t')[1]+'\n'
        i+=1
    return text

# %%
def alldata(lists):
    text=""
    for data in lists:
        text+=text2conll2002(data)
        text+='\n'
    return text

# %%
def alldata_list(lists):
    data_all=[] 
    print(lists)
    for data in lists:
        data_num=[]
        try:
            txt=text2conll2002(data,pos=True).split('\n') # นำไปแปลงเป็น conll2002
            
            for d in txt:
                tt=d.split('\t')
                if d!="":
                    if len(tt)==3:
                        data_num.append((tt[0],tt[1],tt[2]))
                    else:
                        data_num.append((tt[0],tt[1]))
            #print(data_num)
            data_all.append(data_num)
        except:
            print(data)
    #print(data_all)
    return data_all

# %%
def alldata_list_str(lists):
	string=""
	for data in lists:
		string1=""
		for j in data:
			string1+=j[0]+"	"+j[1]+"	"+j[2]+"\n"
		string1+="\n"
		string+=string1
	return string

# %%
def get_data_tag(listd):
	list_all=[]
	c=[]
	for i in listd:
		if i !='':
			c.append((i.split("\t")[0],i.split("\t")[1],i.split("\t")[2]))
		else:
			list_all.append(c)
			c=[]
	return list_all

# %%
def getall(lista):
    ll=[]  
    print(lista)
    for i in lista:
        o=True
        for j in ll:
            if re.sub("\[(.*?)\]","",i)==re.sub("\[(.*?)\]","",j):
                o=False
                break
        if o==True:
            ll.append(i)
            print(i)
    return ll

# %%
def urlify(s):
    s = re.sub(r"\s+", '', s)
    return s

# %%
def get_ner(text):
    #_tokenizer = Tokenizer(custom_dict=trie, engine='newmm')
    #_tokenizer.word_tokenize(text)
    fillter = []
    cut=urlify(text)
    word_cut=_tokenizer.word_tokenize(cut)
    stopwords = set("")
    stopwords.add("(")
    stopwords.add(")")
    for w in word_cut:
      if w not in stopwords:
        fillter.append(w)
    list_word=pos_tag(fillter,engine='perceptron')
    X_test = extract_features([(data,list_word[i][1]) for i,data in enumerate(fillter)])
    y_=crf.predict_single(X_test)
    d.append([(fillter[i],data) for i,data in enumerate(y_)])
    #[(word_cut[i],list_word[i][1],data) for i,data in enumerate(y_)]
    #print(d)
    return True,y_

# %%
def doc2features(doc, i):
    word = doc[i][0]
    postag = doc[i][1]
    # Features from current word
    features={
        'word.word': word,
        'word.isspace':word.isspace(),
        'postag':postag,
        'word.isdigit()': word.isdigit()
    }
    if i > 0:
        prevword = doc[i-1][0]
        postag1 = doc[i-1][1]
        features['word.prevword'] = prevword
        features['word.previsspace']=prevword.isspace()
        features['word.prepostag'] = postag1
        features['word.prevwordisdigit'] = prevword.isdigit()
    else:
        features['BOS'] = True # Special "Beginning of Sequence" tag
    # Features from next word
    if i < len(doc)-1:
        nextword = doc[i+1][0]
        postag1 = doc[i+1][1]
        features['word.nextword'] = nextword
        features['word.nextisspace']=nextword.isspace()
        features['word.nextpostag'] = postag1
        features['word.nextwordisdigit'] = nextword.isdigit()
    else:
        features['EOS'] = True # Special "End of Sequence" tag
    return features

# %%
def extract_features(doc):
    return [doc2features(doc, i) for i in range(len(doc))]

def get_labels(doc):
    return [tag for (token,postag,tag) in doc]

# %% [markdown]
# <h1>จัดการประโยคซ้ำ

# %%
data_not=[]
def Unique(p):
 text=re.sub("<[^>]*>","",p)
 text=re.sub("\[(.*?)\]","",text)
 text=re.sub("\[\/(.*?)\]","",text)   
 if text not in data_not:
  data_not.append(text)
  return True
 else:
  return False

# %% [markdown]
# <h1># เตรียมตัวตัด tag ด้วย re

# %%
pattern = r'\[(.*?)\](.*?)\[\/(.*?)\]'
tokenizer = RegexpTokenizer(pattern) # ใช้ nltk.tokenize.RegexpTokenizer เพื่อตัด [TIME]8.00[/TIME] ให้เป็น ('TIME','ไง','TIME')

# %%
custom_words_list = set(thai_words())
custom_words_list.add('การที่รองอัยการสูงสุด')
custom_words_list.add('ผบ.ตร.')
custom_words_list.add('คำสั่งฟ้อง')
trie = dict_trie(dict_source=custom_words_list)
_tokenizer = Tokenizer(custom_dict=trie, engine='newmm')

# %%
data_not=[]
data1=getall(get_data(file_name+".txt")) # นำคลังเข้าไป แยกออกเป็น list ละบรรทัด
datatofile=alldata_list(data1) # นำไปผ่านขั้นตอน 1 2 3 4
tt=[]
with open(file_name+"-pos.conll","w") as f:
    i=0
    while i<len(datatofile):
        for j in datatofile[i]:
            f.write(j[0]+"\t"+j[1]+"\t"+j[2]+"\n")
        if i+1<len(datatofile):
            f.write("\n")
        i+=1

with open(file_name+".conll","w") as f:
    i=0
    while i<len(datatofile):
        for j in datatofile[i]:
            f.write(j[0]+"\t"+j[2]+"\n")
        if i+1<len(datatofile):
            f.write("\n")
        i+=1
# Out:
# ['[Prepositions]แต่[/Prepositions][noun]สิ่ง[/noun][SS Conjunctions]ที่[/SS Conjunctions] [intransitive verb] ชี้[/intransitive verb] [word before verb]ให้[/word before verb][transitive verb]เห็น[/transitive verb][SS Conjunctions]ว่า[/SS Conjunctions]
 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('กระบวนการ', 'NCMN', 'noun'),
#   ('รัฐธรรมนูญ', 'NCMN', 'noun'),
#   ('ก็', 'JSBR', 'wordbeforeverb'),
#   ('คือ', 'VSTA', 'transitiveverb'),
#   ('เมื่อ', 'JSBR', 'Timeexpressionword'),
#   ('ก่อน', 'RPRE', 'Timeexpressionword'),
#   ('การ', 'FIXN', 'noun'),
#   ('ชุมนุม', 'VACT', 'noun'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('บุคคล', 'NCMN', 'noun'),
#   ('ใด', 'DIAC', 'Pronouns'),
#   ('ก็ตาม', 'JCRG', 'Adverbs'),
#   ('ก็', 'JSBR', 'wordbeforeverb'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('อ้าง', 'VACT', 'transitiveverb'),
#   ('ตาม', 'RPRE', 'Prepositions'),
#   ('รัฐธรรมนูญ', 'NCMN', 'noun'),
#   ('มาตรา', 'NCMN', 'noun'),
#   ('25', 'NCNM', 'Numeralword'),
#   ('อ้าง', 'PNTR', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('สิทธิ', 'NCMN', 'noun'),
#   ('เสรีภาพ', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ศักดิ์ศรี', 'NCMN', 'noun'),
#   ('ความเป็นมนุษย์', 'NCMN', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('การ', 'FIXN', 'noun'),
#   ('ชุมนุม', 'VACT', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('วัน', 'NCMN', 'Timeexpressionword'),
#   ('นี้', 'DDAC', 'Pronouns'),
#   ('เมื่อ', 'JSBR', 'Timeexpressionword'),
#   ('การ', 'FIXN', 'noun'),
#   ('ชุมนุม', 'VACT', 'noun'),
#   ('ไป', 'XVAE', 'transitiveverb'),
#   ('ถึง', 'RPRE', 'Prepositions'),
#   ('ระดับ', 'NCMN', 'noun'),
#   ('หนึ่ง', 'DCNM', 'Numeralword'),
#   ('ก็', 'JSBR', 'PhrasalVerbs'),
#   ('ไป', 'VACT', 'PhrasalVerbs'),
#   ('ละเมิด', 'NCMN', 'transitiveverb'),
#   ('สิทธิ', 'NCMN', 'noun'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('บุคคล', 'NCMN', 'Nounphrase'),
#   ('อื่น', 'DIAC', 'Nounphrase'),
#   ('มากมาย', 'ADVN', 'Adverbs'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('เคารพ', 'VSTA', 'transitiveverb'),
#   ('กฎหมาย', 'NCMN', 'noun'),
#   ('ต่างๆ', 'DIAC', 'Adverbs'),
#   ('มากมาย', 'ADVN', 'Adverbs'),
#   ('จึง', 'XVBM', 'SSConjunctions'),
#   ('ทำให้', 'VACT', 'transitiveverb'),
#   ('การ', 'FIXN', 'noun'),
#   ('ชุมนุม', 'VACT', 'noun'),
#   ('ใน', 'RPRE', 'Timeexpressionword'),
#   ('ขณะนี้', 'NCMN', 'Timeexpressionword'),
#   ('มิ', 'NEG', 'Negator'),
#   ('ได้', 'XVAE', 'wordbeforeverb'),
#   ('เป็นไปตาม', 'VACT', 'PhrasalVerbs'),
#   ('กระบวน', 'NCMN', 'noun'),
#   ('การปกครอง', 'VATT', 'noun'),
#   ('ตาม', 'RPRE', 'Adverbs'),
#   ('ระบอบ', 'NCMN', 'noun'),
#   ('ประชาธิปไตย', 'NCMN', 'noun'),
#   ('อัน', 'PREL', 'PhrasalVerbs'),
#   ('มี', 'VSTA', 'PhrasalVerbs'),
#   ('พระมหากษัตริย์', 'NCMN', 'noun'),
#   ('ทรง', 'NCMN', 'transitiveverb'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('พระ', 'NCMN', 'noun'),
#   ('ประมุข', 'VACT', 'noun'),
#   ('ขณะที่', 'JSBR', 'Timeexpressionword'),
#   ('การ', 'FIXN', 'noun'),
#   ('ชุมนุม', 'VACT', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('วัน', 'NCMN', 'Timeexpressionword'),
#   ('นั้น', 'DDAC', 'Pronouns'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('แกนนำ', 'NCMN', 'noun'),
#   ('ขึ้น', 'XVAE', 'PhrasalVerbs'),
#   ('ปราศรัย', 'NCMN', 'PhrasalVerbs'),
#   ('ประมาณ', 'DIBQ', 'wordbeforenumeral'),
#   ('10', 'DCNM', 'Numeralword'),
#   ('คน', 'CNIT', 'Qualitativenoun'),
#   ('และ', 'JCRG', 'O'),
#   ('ทำให้', 'VACT', 'PhrasalVerbs'),
#   ('เมื่อคืนนี้', 'DDAC', 'Timeexpressionword'),
#   ('(', 'PUNC', 'O'),
#   ('12', 'NCNM', 'Numeralword'),
#   ('ส.ค.', 'DCNM', 'abbreviation'),
#   ('63', 'NCNM', 'Numeralword'),
#   (')', 'PUNC', 'O'),
#   ('ทาง', 'RPRE', 'Nounphrase'),
#   ('แกนนำ', 'NCMN', 'Nounphrase'),
#   ('อ้างว่า', 'JSBR', 'PhrasalVerbs'),
#   ('มี', 'VSTA', 'PhrasalVerbs'),
#   ('ตำรวจ', 'NCMN', 'noun'),
#   ('ไป', 'XVAE', 'PhrasalVerbs'),
#   ('สังเกตการณ์', 'VACT', 'PhrasalVerbs'),
#   ('บริเวณ', 'NCMN', 'Nounphrase'),
#   ('รอบ', 'RPRE', 'Nounphrase'),
#   ('ที่พัก', 'NCMN', 'Nounphrase'),
#   ('เพื่อ', 'JSBR', 'SSConjunctions'),
#   ('รอ', 'VSTA', 'PhrasalVerbs'),
#   ('ควบคุม', 'VACT', 'PhrasalVerbs'),
#   ('ตัว', 'CNIT', 'noun'),
#   ('แต่', 'JCRG', 'Prepositions'),
#   ('จนถึง', 'RPRE', 'Prepositions'),
#   ('ขณะนี้', 'ADVS', 'Timeexpressionword'),
#   ('ยัง', 'XVBM', 'wordbeforeverb'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('การ', 'FIXN', 'noun'),
#   ('ดำเนินการ', 'VACT', 'noun'),
#   ('ใดๆ', 'DIAC', 'Adverbs')],
#  [('ขณะที่', 'JSBR', 'Timeexpressionword'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('รายงาน', 'NCMN', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('การ', 'FIXN', 'noun'),
#   ('ดักรอ', 'VACT', 'noun'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('เจ้าหน้าที่', 'NCMN', 'noun'),
#   ('ตาม', 'RPRE', 'Adverbs'),
#   ('ที่พัก', 'NCMN', 'noun'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('แกนนำ', 'NCMN', 'noun'),
#   ('สืบ', 'VACT', 'SSConjunctions'),
#   ('เนื่องมาจาก', 'JSBR', 'SSConjunctions'),
#   ('เมื่อวาน', 'NCMN', 'Timeexpressionword'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('วันสำคัญ', 'NCMN', 'noun'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('ชาติ', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('แกนนำ', 'NCMN', 'noun'),
#   ('ประกาศ', 'VACT', 'PhrasalVerbs'),
#   ('ไว้', 'XVAE', 'PhrasalVerbs'),
#   ('ก่อนหน้านี้', 'DDAC', 'Timeexpressionword'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('เซอร์ไพรส์', 'NCMN', 'noun'),
#   ('ทำให้', 'VACT', 'transitiveverb'),
#   ('เจ้าหน้าที่', 'NCMN', 'noun'),
#   ('เป็นกังวล', 'NCMN', 'PhrasalVerbs'),
#   ('จึง', 'XVBM', 'SSConjunctions'),
#   ('ออกมา', 'XVAE', 'PhrasalVerbs'),
#   ('สังเกตการณ์', 'NCMN', 'PhrasalVerbs'),
#   ('บริเวณ', 'NCMN', 'noun'),
#   ('ใกล้', 'RPRE', 'Adverbs'),
#   ('ที่พัก', 'NCMN', 'noun'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('แกนนำ', 'NCMN', 'noun')],
#  [],
#  [('ทั้งนี้', 'JSBR', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('เวลา', 'NCMN', 'Timeexpressionword'),
#   ('14.00', 'NCNM', 'Numeralword'),
#   ('น.', 'CMTR', 'abbreviation'),
#   ('วัน', 'NCMN', 'Timeexpressionword'),
#   ('นี้', 'DDAC', 'Pronouns'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('สภ.', 'VACT', 'noun'),
#   ('คลอง', 'NCMN', 'noun'),
#   ('หลวง', 'NCMN', 'noun'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('กลุ่ม', 'NCMN', 'noun'),
#   ('รัก', 'NCMN', 'noun'),
#   ('แผ่นดิน', 'NCMN', 'noun'),
#   ('เกิด', 'VSTA', 'noun'),
#   ('เข้า', 'VACT', 'PhrasalVerbs'),
#   ('แจ้งความ', 'NCMN', 'PhrasalVerbs'),
#   ('ร้องทุกข์', 'NCMN', 'PhrasalVerbs'),
#   ('ให้', 'JSBR', 'PhrasalVerbs'),
#   ('ดำเนินคดี', 'VSTA', 'PhrasalVerbs'),
#   ('กับ', 'RPRE', 'Prepositions'),
#   ('รศ.', 'NTTL', 'wordbeforenoun'),
#   ('เกศินี', 'NPRP', 'noun'),
#   ('วิ', 'NCMN', 'noun'),
#   ('ฑูร', 'NCMN', 'noun'),
#   ('ชาติ', 'NCMN', 'noun'),
#   ('อธิการบดี', 'NCMN', 'noun'),
#   ('มหาวิทยาลัย', 'NCMN', 'noun'),
#   ('ธรรมศาสตร์', 'NPRP', 'noun'),
#   (',', 'PUNC', 'O'),
#   ('ผศ.', 'NTTL', 'wordbeforenoun'),
#   ('ดร.', 'NTTL', 'wordbeforenoun'),
#   ('ปริญญา', 'NPRP', 'noun'),
#   ('เทวา', 'NPRP', 'noun'),
#   ('นฤ', 'NCMN', 'noun'),
#   ('มิตร', 'NCMN', 'noun'),
#   ('กุล', 'NCMN', 'noun'),
#   ('รอง', 'VATT', 'noun'),
#   ('อธิการบดี', 'NCMN', 'noun'),
#   ('ฝ่าย', 'NCMN', 'noun'),
#   ('ความยั่งยืน', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('บริหาร', 'VACT', 'transitiveverb'),
#   ('ศูนย์', 'NCMN', 'noun'),
#   ('รังสิต', 'NCMN', 'noun'),
#   ('มหาวิทยาลัย', 'NCMN', 'noun'),
#   ('ธรรมศาสตร์', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('คณะ', 'NCMN', 'noun'),
#   ('ผู้', 'PREL', 'noun'),
#   ('จัด', 'VACT', 'noun'),
#   ('ชุมนุม', 'NCMN', 'noun'),
#   ('“', 'NCMN', 'noun'),
#   ('ธรรมศาสตร์', 'NCMN', 'noun'),
#   ('จะ', 'XVBM', 'noun'),
#   ('ไม่', 'NEG', 'noun'),
#   ('ทน', 'VSTA', 'noun'),
#   ('”', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('ลาน', 'VACT', 'noun'),
#   ('พญานาค', 'VACT', 'noun'),
#   ('มหาวิทยาลัย', 'NCMN', 'noun'),
#   ('ธรรมศาสตร์', 'NCMN', 'noun'),
#   ('ศูนย์', 'NLBL', 'noun'),
#   ('รังสิต', 'VSTA', 'noun'),
#   ('เมื่อ', 'JSBR', 'SSConjunctions'),
#   ('วันที่', 'JSBR', 'SSConjunctions'),
#   ('10', 'NCNM', 'Timeexpressionword'),
#   ('ส.ค.', 'DCNM', 'Timeexpressionword'),
#   ('63', 'NCNM', 'Timeexpressionword'),
#   ('ฐาน', 'NCMN', 'O'),
#   ('ให้การ', 'VACT', 'PhrasalVerbs'),
#   ('สนับสนุน', 'VACT', 'PhrasalVerbs'),
#   ('การ', 'FIXN', 'noun'),
#   ('ชุมนุม', 'VACT', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('การปราศรัย', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('จาบจ้วง', 'VACT', 'PhrasalVerbs'),
#   ('ก้าวล่วง', 'NCMN', 'PhrasalVerbs'),
#   ('สถาบัน', 'NCMN', 'noun'),
#   ('พระมหากษัตริย์', 'NCMN', 'noun'),
#   ('รวมทั้ง', 'JCRG', 'NounConjunctions'),
#   ('ยุยง', 'NCMN', 'PhrasalVerbs'),
#   ('ปลุกปั่น', 'NCMN', 'PhrasalVerbs'),
#   ('ให้', 'JSBR', 'PhrasalVerbs'),
#   ('เกิด', 'VSTA', 'PhrasalVerbs'),
#   ('ความขัดแย้ง', 'NCMN', 'noun'),
#   ('แตกแยก', 'VSTA', 'noun'),
#   ('ภายใน', 'RPRE', 'Prepositions'),
#   ('ประเทศ', 'NCMN', 'noun')],
#  [('เบื้องต้น', 'NCMN', 'SSConjunctions'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('บ้าน', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('ถูก', 'XVAM', 'transitiveverb'),
#   ('ไฟ', 'VACT', 'noun'),
#   ('ไหม้', 'VACT', 'intransitiveverb'),
#   ('เสียหาย', 'NCMN', 'transitiveverb'),
#   ('76', 'NCMN', 'Numeralword'),
#   ('หลังคาเรือน', 'NCMN', 'Qualitativenoun'),
#   ('ตรวจสอบ', 'VACT', 'transitiveverb'),
#   ('แล้ว', 'XVAE', 'wordafterverb'),
#   ('พบ', 'VACT', 'transitiveverb'),
#   ('เจ้าของบ้าน', 'NCMN', 'noun'),
#   ('ต้น', 'VATT', 'Sequenceword'),
#   ('เพลิง', 'ADVN', 'noun'),
#   ('บาดเจ็บ', 'NCMN', 'intransitiveverb'),
#   ('บริเวณ', 'NCMN', 'Nounphrase'),
#   ('แขนขวา', 'NCMN', 'Nounphrase'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('หน้าผาก', 'NCMN', 'noun'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('อาสา', 'NCMN', 'noun'),
#   ('กู้ภัย', 'NCMN', 'noun'),
#   ('ศีรษะ', 'NCMN', 'noun'),
#   ('แตก', 'NCMN', 'intransitiveverb'),
#   ('หลัง', 'VATT', 'wordbeforeverb'),
#   ('ถูก', 'XVAM', 'transitiveverb'),
#   ('เศษ', 'VACT', 'noun'),
#   ('หลังคา', 'NCMN', 'noun'),
#   ('หล่น', 'NCMN', 'transitiveverb'),
#   ('ใส่', 'VACT', 'transitiveverb'),
#   ('ศีรษะ', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('หญิง', 'NCMN', 'noun'),
#   ('ชรา', 'NCMN', 'Adjectives'),
#   ('สำลัก', 'NCMN', 'transitiveverb'),
#   ('ควัน', 'NCMN', 'noun'),
#   ('1', 'NCNM', 'Numeralword'),
#   ('คน', 'CNIT', 'Qualitativenoun'),
#   ('ประชาชน', 'CNIT', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('บ้าน', 'NCMN', 'noun'),
#   ('อยู่', 'XVAE', 'transitiveverb'),
#   ('ใกล้เคียง', 'RPRE', 'Adverbs'),
#   ('จุด', 'NCMN', 'noun'),
#   ('เกิดเหตุ', 'NCMN', 'noun'),
#   ('เปิดเผย', 'VSTA', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('หลัง', 'NCMN', 'wordbeforeverb'),
#   ('เกิด', 'VSTA', 'transitiveverb'),
#   ('แสง', 'NCMN', 'noun'),
#   ('เพลิง', 'NCMN', 'noun'),
#   ('ก็', 'JSBR', 'wordbeforeverb'),
#   ('ช่วยกัน', 'ADVN', 'PhrasalVerbs'),
#   ('แจ้ง', 'NCMN', 'PhrasalVerbs'),
#   ('เหตุ', 'NCMN', 'noun'),
#   ('กับ', 'RPRE', 'Prepositions'),
#   ('เจ้าหน้าที่', 'NCMN', 'noun'),
#   ('ทันที', 'ADVN', 'Adverbs'),
#   ('รอ', 'VSTA', 'transitiveverb'),
#   ('เกือบ', 'DIBQ', 'wordbeforenumeral'),
#   ('40', 'DCNM', 'Numeralword'),
#   ('นาที', 'CMTR', 'Qualitativenoun'),
#   ('เจ้าหน้าที่', 'NCMN', 'noun'),
#   ('ถึง', 'RPRE', 'PhrasalVerbs'),
#   ('เข้า', 'VACT', 'PhrasalVerbs'),
#   ('ที่เกิดเหตุ', 'NCMN', 'noun'),
#   ('ได้', 'XVAE', 'Adverbs'),
#   ('ส่วนหนึ่ง', 'ADVN', 'noun'),
#   ('เพราะ', 'JSBR', 'Prepositions'),
#   ('ทางเข้า', 'NCMN', 'noun'),
#   ('ซอย', 'NCMN', 'noun'),
#   ('คับแคบ', 'NCMN', 'Adjectives'),
#   ('ส่วน', 'NCMN', 'noun'),
#   ('ที่เกิดเหตุ', 'NCMN', 'noun'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('บ้าน', 'NCMN', 'noun'),
#   ('2', 'NCNM', 'Numeralword'),
#   ('ชั้น', 'CNIT', 'Qualitativenoun'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('อายุ', 'NCMN', 'noun'),
#   ('ประมาณ', 'DIBQ', 'wordbeforenumeral'),
#   ('40', 'DCNM', 'Numeralword'),
#   ('-', 'PUNC', 'Numeralword'),
#   ('50', 'DCNM', 'Numeralword'),
#   ('ปี', 'CMTR', 'Qualitativenoun'),
#   ('มา', 'XVAE', 'transitiveverb'),
#   ('แล้ว', 'ADVN', 'wordafterverb'),
#   ('ก็', 'JSBR', 'wordbeforeverb'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('/[', 'NCMN', 'transitiveverb'),
#   ('transitiveverb', 'NCMN', 'transitiveverb'),
#   ('][', 'NCMN', 'transitiveverb'),
#   ('noun', 'NCMN', 'transitiveverb'),
#   (']', 'NCMN', 'transitiveverb'),
#   ('ปัจจัย', 'NCMN', 'transitiveverb'),
#   ('ให้', 'JSBR', 'transitiveverb'),
#   ('ไฟ', 'NCMN', 'noun'),
#   ('ลุกลาม', 'VSTA', 'intransitiveverb'),
#   ('รวดเร็ว', 'VATT', 'Adverbs'),
#   ('ด้วย', 'RPRE', 'Adverbs'),
#   ('อีก', 'DDBQ', 'Adverbs'),
#   ('ทั้ง', 'DDBQ', 'Adverbs'),
#   ('เมื่อ', 'JSBR', 'Timeexpressionword'),
#   ('ปี', 'NCMN', 'Timeexpressionword'),
#   ('2561', 'NCNM', 'Timeexpressionword'),
#   ('ที่นี่', 'PREL', 'noun'),
#   ('เคย', 'XVMM', 'wordbeforeverb'),
#   ('เกิด', 'VSTA', 'transitiveverb'),
#   ('เพลิงไหม้', 'NCMN', 'noun'),
#   ('ใหญ่', 'VATT', 'Adjectives'),
#   ('มา', 'XVAE', 'transitiveverb'),
#   ('แล้ว', 'XVAE', 'wordafterverb'),
#   ('ใน', 'RPRE', 'Timeexpressionword'),
#   ('ครั้งนั้น', 'NCMN', 'Timeexpressionword'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('บ้านเรือน', 'NCMN', 'Nounphrase'),
#   ('ประชาชน', 'NCMN', 'Nounphrase'),
#   ('ถูก', 'XVAM', 'transitiveverb'),
#   ('ไฟ', 'VACT', 'noun'),
#   ('ไหม้', 'VACT', 'intransitiveverb'),
#   ('เสียหาย', 'NCMN', 'transitiveverb'),
#   ('ประมาณ', 'DIBQ', 'wordbeforenumeral'),
#   ('100', 'DCNM', 'Numeralword'),
#   ('หลังคา', 'CNIT', 'Qualitativenoun'),
#   ('หลัง', 'RPRE', 'wordbeforeverb'),
#   ('เกิด', 'VSTA', 'transitiveverb'),
#   ('เพลิง', 'NCMN', 'noun'),
#   ('ไหม้', 'NCMN', 'intransitiveverb'),
#   ('ส่งผล', 'VACT', 'transitiveverb'),
#   ('ให้', 'RPRE', 'transitiveverb'),
#   ('ไฟฟ้า', 'NCMN', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('พื้นที่', 'NCMN', 'noun'),
#   ('ดับ', 'NCMN', 'intransitiveverb'),
#   ('เจ้าหน้าที่', 'NCMN', 'noun'),
#   ('อยู่', 'VSTA', 'PhrasalVerbs'),
#   ('ระหว่าง', 'RPRE', 'PhrasalVerbs'),
#   ('ดำเนินการ', 'VACT', 'PhrasalVerbs'),
#   ('แก้ไข', 'VACT', 'PhrasalVerbs'),
#   ('สำหรับ', 'RPRE', 'Prepositions'),
#   ('ประชาชน', 'NCMN', 'noun'),
#   ('ชาว', 'VSTA', 'noun'),
#   ('ซอย', 'NCMN', 'noun'),
#   ('ตากสิน', 'VACT', 'noun'),
#   ('23', 'NCNM', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('ประสบ', 'VSTA', 'transitiveverb'),
#   ('เหตุ', 'NCMN', 'noun'),
#   ('อัคคีภัย', 'NCMN', 'noun'),
#   ('เจ้าหน้าที่', 'NCMN', 'noun'),
#   ('กรุงเทพมหานคร', 'NPRP', 'noun'),
#   ('เข้า', 'VACT', 'PhrasalVerbs'),
#   ('ดูแล', 'VACT', 'PhrasalVerbs'),
#   ('เบื้องต้น', 'ADVN', 'Adjectives'),
#   ('จัด', 'VACT', 'transitiveverb'),
#   ('ที่พัก', 'VACT', 'noun'),
#   ('ค้าง', 'NCMN', 'transitiveverb'),
#   ('ชั่วคราว', 'VATT', 'Adverbs'),
#   ('ภายใน', 'RPRE', 'Prepositions'),
#   ('วัด', 'VACT', 'noun'),
#   ('สิน', 'NCMN', 'noun'),
#   ('ติ', 'NCMN', 'noun'),
#   ('ธรรมา', 'NCMN', 'noun'),
#   ('ราม', 'NCMN', 'noun'),
#   ('ซึ่ง', 'PREL', 'SSConjunctions'),
#   ('ตั้งอยู่', 'VSTA', 'transitiveverb'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('ชุมชน', 'NCMN', 'noun'),
#   ('อีก', 'DDBQ', 'Adverbs'),
#   ('ทั้ง', 'JCRG', 'Adverbs'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('ประชาชน', 'NCMN', 'noun'),
#   ('มูลนิธิ', 'VSTA', 'noun'),
#   ('ปอเต็กตึ้ง', 'NCMN', 'noun'),
#   ('นำ', 'VACT', 'transitiveverb'),
#   ('เสื้อผ้า', 'NCMN', 'noun'),
#   ('อาหาร', 'NCMN', 'noun'),
#   ('บริการ', 'VACT', 'PhrasalVerbs'),
#   ('ช่วยเหลือ', 'VACT', 'PhrasalVerbs'),
#   ('ผู้', 'PPRS', 'noun'),
#   ('ประสบ', 'VSTA', 'noun'),
#   ('เหตุ', 'VSTA', 'noun'),
#   ('ด้วย', 'ADVN', 'O')],
#  [('วัน', 'NCMN', 'Timeexpressionword'),
#   ('นี้', 'DDAC', 'Pronouns'),
#   ('(', 'PUNC', 'O'),
#   ('12', 'NCNM', 'Numeralword'),
#   (']', 'NCMN', 'O'),
#   ('ส.ค.', 'CNIT', 'abbreviation'),
#   ('2563', 'NCNM', 'Numeralword'),
#   (')', 'PUNC', 'O'),
#   ('พ.ต.อ.', 'NCMN', 'wordbeforenoun'),
#   ('กฤษณะ', 'NCMN', 'noun'),
#   ('พัฒนะ', 'NCMN', 'noun'),
#   ('เจริญ', 'NCMN', 'noun'),
#   ('รอง', 'VATT', 'noun'),
#   ('โฆษก', 'NCMN', 'noun'),
#   ('สำนักงานตำรวจแห่งชาติ', 'NCMN', 'noun'),
#   ('เปิดเผย', 'VACT', 'transitiveverb'),
#   ('ถึง', 'RPRE', 'SSConjunctions'),
#   ('เหตุการณ์', 'NCMN', 'noun'),
#   ('หญิง', 'NCMN', 'noun'),
#   ('วัย', 'NCMN', 'noun'),
#   ('37', 'DCNM', 'Numeralword'),
#   ('ปี', 'CMTR', 'Qualitativenoun'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('ชน', 'NCMN', 'transitiveverb'),
#   ('เบนซ์', 'NCMN', 'noun'),
#   ('ชน', 'NCMN', 'transitiveverb'),
#   ('คน', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('รถ', 'NCMN', 'noun'),
#   ('เสียหาย', 'VSTA', 'intransitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('ตำรวจ', 'NCMN', 'noun'),
#   ('ยัง', 'XVBM', 'wordbeforeverb'),
#   ('อยู่', 'VSTA', 'transitiveverb'),
#   ('ระหว่าง', 'RPRE', 'noun'),
#   ('การ', 'FIXN', 'noun'),
#   ('สอบปากคำ', 'VACT', 'noun'),
#   ('เนื่องจาก', 'JSBR', 'SSConjunctions'),
#   ('ผู้ต้องหา', 'NCMN', 'noun'),
#   ('ยัง', 'XVBM', 'wordbeforeverb'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('สามารถ', 'XVAM', 'Adverbs'),
#   ('ให้การ', 'VACT', 'transitiveverb'),
#   ('ได้', 'XVAE', 'Adverbs')],
#  [('เบื้องต้น', 'VATT', 'SSConjunctions'),
#   ('พนักงานสอบสวน', 'NCMN', 'noun'),
#   ('แจ้ง', 'NCMN', 'transitiveverb'),
#   ('4', 'NCNM', 'Numeralword'),
#   ('ข้อกล่าวหา', 'CNIT', 'noun'),
#   ('คือ', 'VSTA', 'transitiveverb'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('ใน', 'RPRE', 'SSConjunctions'),
#   ('ขณะ', 'NCMN', 'SSConjunctions'),
#   ('เมา', 'DDAC', 'transitiveverb'),
#   ('สุรา', 'NCMN', 'noun'),
#   ('หรือ', 'JCRG', 'NounConjunctions'),
#   ('สิ่ง', 'NCMN', 'Nounphrase'),
#   ('ของมึนเมา', 'NCMN', 'Nounphrase'),
#   ('อย่าง', 'FIXV', 'Nounphrase'),
#   ('อื่น', 'DIAC', 'Nounphrase'),
#   (',', 'PUNC', 'O'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('โดย', 'RPRE', 'Prepositions'),
#   ('ประมาท', 'VACT', 'noun'),
#   ('เฉี่ยว', 'NCMN', 'transitiveverb'),
#   ('ชน', 'NCMN', 'transitiveverb'),
#   ('ผู้อื่น', 'NCMN', 'noun'),
#   ('เป็นเหตุให้', 'VACT', 'PhrasalVerbs'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('ผู้', 'PPRS', 'noun'),
#   ('ได้รับบาดเจ็บ', 'VACT', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ทรัพย์สิน', 'NCMN', 'noun'),
#   ('เสียหาย', 'NCMN', 'intransitiveverb'),
#   (',', 'PUNC', 'O'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('หยุด', 'VSTA', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ให้', 'VACT', 'transitiveverb'),
#   ('ความช่วยเหลือ', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ต่อสู้', 'NCMN', 'PhrasalVerbs'),
#   ('ขัดขวาง', 'NCMN', 'PhrasalVerbs'),
#   ('เจ้าพนักงาน', 'NCMN', 'noun'),
#   ('ซึ่ง', 'PREL', 'SSConjunctions'),
#   ('ปฏิบัติการ', 'VACT', 'transitiveverb'),
#   ('ตาม', 'RPRE', 'Adverbs'),
#   ('หน้าที่', 'NCMN', 'noun')],
#  [('ซึ่ง', 'JSBR', 'SSConjunctions'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('ข้อหา', 'NCMN', 'Nounphrase'),
#   ('ความผิด', 'NCMN', 'Nounphrase'),
#   ('ดังกล่าว', 'DDAC', 'Pronouns'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('อัตรา', 'NCMN', 'noun'),
#   ('โทษ', 'NCMN', 'noun'),
#   ('อยู่', 'VSTA', 'transitiveverb'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('อำนาจ', 'NCMN', 'noun'),
#   ('ศาลแขวง', 'NCMN', 'noun'),
#   ('หาก', 'JSBR', 'SSConjunctions'),
#   ('ผู้ต้องหา', 'VACT', 'noun'),
#   ('ให้การ', 'NCMN', 'PhrasalVerbs'),
#   ('รับสารภาพ', 'NCMN', 'PhrasalVerbs'),
#   ('พนักงานสอบสวน', 'NCMN', 'noun'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('ดำเนินการ', 'VACT', 'transitiveverb'),
#   ('ยื่นฟ้อง', 'ADVN', 'transitiveverb'),
#   ('ต่อ', 'RPRE', 'Prepositions'),
#   ('ศาลแขวง', 'NCMN', 'noun'),
#   ('ภายใน', 'RPRE', 'Prepositions'),
#   ('ระยะ', 'NCMN', 'noun'),
#   ('เวลา', 'NCMN', 'noun'),
#   ('48', 'NCNM', 'Numeralword'),
#   ('ชั่วโมง', 'CMTR', 'Qualitativenoun'),
#   ('แต่', 'JCRG', 'SSConjunctions'),
#   ('หาก', 'JSBR', 'SSConjunctions'),
#   ('ให้การ', 'VACT', 'PhrasalVerbs'),
#   ('ปฏิเสธ', 'VACT', 'PhrasalVerbs'),
#   ('พนักงานสอบสวน', 'NCMN', 'noun'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('ยื่น', 'VACT', 'PhrasalVerbs'),
#   ('ขอ', 'VACT', 'PhrasalVerbs'),
#   ('ผัด', 'NCMN', 'PhrasalVerbs'),
#   ('ฟ้อง', 'NCMN', 'PhrasalVerbs'),
#   ('ฝากขัง', 'NCMN', 'PhrasalVerbs'),
#   ('ผู้ต้องหา', 'NCMN', 'noun'),
#   ('ต่อ', 'RPRE', 'Prepositions'),
#   ('ศาล', 'NCMN', 'noun'),
#   ('พร้อม', 'VSTA', 'Adverbs'),
#   ('สอบสวน', 'NCMN', 'transitiveverb'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('รวบรวม', 'VACT', 'transitiveverb'),
#   ('พยาน', 'NCMN', 'noun'),
#   ('หลักฐาน', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('เกี่ยวข้อง', 'VSTA', 'transitiveverb'),
#   ('อื่นๆ', 'DIAC', 'Adverbs'),
#   ('เพื่อ', 'JSBR', 'Prepositions'),
#   ('ดำเนินการ', 'VACT', 'transitiveverb'),
#   ('ตาม', 'RPRE', 'O'),
#   ('ขั้นตอน', 'NCMN', 'noun'),
#   ('กฎหมาย', 'NCMN', 'noun')],
#  [('ด้าน', 'NCMN', 'SSConjunctions'),
#   ('พล.ต.ต.', 'NCMN', 'wordbeforenoun'),
#   ('พัฒนา', 'VACT', 'noun'),
#   ('เพศ', 'NCMN', 'noun'),
#   ('ย', 'NCMN', 'noun'),
#   ('นาวิน', 'NCMN', 'noun'),
#   ('ผู้บังคับการ', 'NCMN', 'noun'),
#   ('ตำรวจนครบาล', 'VACT', 'noun'),
#   ('2', 'DCNM', 'Numeralword'),
#   ('เปิดเผย', 'VACT', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('ขณะ', 'NCMN', 'Timeexpressionword'),
#   ('นี้', 'DDAC', 'Pronouns'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('ผู้เสียหาย', 'NCMN', 'noun'),
#   ('เข้า', 'VACT', 'wordbeforeverb'),
#   ('แจ้งความ', 'NCMN', 'transitiveverb'),
#   ('ดำเนินคดี', 'NCMN', 'intransitiveverb'),
#   ('แล้ว', 'JSBR', 'wordafterverb'),
#   ('3', 'DCNM', 'Numeralword'),
#   ('คน', 'CNIT', 'Qualitativenoun'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('ผู้ขับขี่', 'NCMN', 'noun'),
#   ('รถยนต์', 'NCMN', 'noun'),
#   ('1', 'NCNM', 'Numeralword'),
#   ('คัน', 'CNIT', 'Qualitativenoun'),
#   ('ถูก', 'XVAM', 'transitiveverb'),
#   ('เฉี่ยว', 'VACT', 'transitiveverb'),
#   ('ชน', 'NCMN', 'transitiveverb'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('ถนน', 'NCMN', 'noun'),
#   ('กำแพงเพชร', 'NCMN', 'noun'),
#   ('1', 'NCNM', 'Numeralword'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('รถจักรยานยนต์', 'NCMN', 'noun'),
#   ('2', 'NCNM', 'Numeralword'),
#   ('คัน', 'CNIT', 'Qualitativenoun'),
#   ('ถูก', 'XVAM', 'transitiveverb'),
#   ('เฉี่ยว', 'VACT', 'intransitiveverb'),
#   ('ชน', 'NCMN', 'intransitiveverb'),
#   ('บริเวณ', 'NCMN', 'Prepositions'),
#   ('สะพาน', 'NCMN', 'noun'),
#   ('ข้าม', 'VACT', 'noun'),
#   ('แยก', 'VACT', 'noun'),
#   ('กำแพงเพชร', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('หน้า', 'NCMN', 'Prepositions'),
#   ('ธนาคาร', 'NCMN', 'noun'),
#   ('ทหาร', 'NCMN', 'noun'),
#   ('ไทย', 'NPRP', 'noun'),
#   ('ถนน', 'NCMN', 'noun'),
#   ('พหลโยธิน', 'NCMN', 'noun'),
#   ('โดย', 'RPRE', 'SSConjunctions'),
#   ('ทั้ง', 'JCRG', 'Numeralword'),
#   ('3', 'DCNM', 'Numeralword'),
#   ('คน', 'CNIT', 'Qualitativenoun'),
#   ('ได้รับ', 'VSTA', 'transitiveverb'),
#   ('บาดเจ็บ', 'NCMN', 'intransitiveverb'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('รถ', 'NCMN', 'noun'),
#   ('ได้รับ', 'VSTA', 'transitiveverb'),
#   ('ความเสียหาย', 'NCMN', 'noun')],
#  [('สำหรับ', 'JSBR', 'Prepositions'),
#   ('เหตุการณ์', 'NCMN', 'noun'),
#   ('นี้', 'DDAC', 'Pronouns'),
#   ('เกิดขึ้น', 'VSTA', 'O'),
#   ('เมื่อ', 'JSBR', 'O'),
#   ('เวลา', 'NCMN', 'Timeexpressionword'),
#   ('ประมาณ', 'DIBQ', 'wordbeforenumeral'),
#   ('23.00', 'DCNM', 'Numeralword'),
#   ('น.', 'CMTR', 'abbreviation'),
#   ('โดย', 'RPRE', 'O'),
#   ('หญิง', 'NCMN', 'noun'),
#   ('วัย', 'NPRP', 'noun'),
#   ('37', 'DCNM', 'Numeralword'),
#   ('ปี', 'CMTR', 'Qualitativenoun'),
#   ('ก่อ', 'CMTR', 'transitiveverb'),
#   ('เหตุ', 'NCMN', 'noun'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('เบนซ์', 'NCMN', 'noun'),
#   ('เฉี่ยว', 'VACT', 'transitiveverb'),
#   ('ชน', 'NCMN', 'transitiveverb'),
#   ('คน', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ชน', 'NCMN', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('เสียหาย', 'VSTA', 'intransitiveverb'),
#   ('หลาย', 'DIBQ', 'Numeralword'),
#   ('คัน', 'CNIT', 'Qualitativenoun'),
#   ('ก่อน', 'RPRE', 'wordbeforeverb'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('หลบหนี', 'NCMN', 'transitiveverb'),
#   ('ซึ่ง', 'PREL', 'SSConjunctions'),
#   ('พลเมือง', 'VSTA', 'noun'),
#   ('ดี', 'ADVN', 'Adjectives'),
#   ('ขี่', 'NCMN', 'transitiveverb'),
#   ('รถจักรยานยนต์', 'NCMN', 'noun'),
#   ('ดัก', 'VACT', 'PhrasalVerbs'),
#   ('ติดตาม', 'VACT', 'PhrasalVerbs'),
#   ('ไว้', 'XVAE', 'PhrasalVerbs'),
#   ('ได้', 'XVAE', 'PhrasalVerbs'),
#   ('โดย', 'JSBR', 'Prepositions'),
#   ('รถ', 'NCMN', 'noun'),
#   ('คัน', 'CNIT', 'Qualitativenoun'),
#   ('ดังกล่าว', 'DDAC', 'Pronouns'),
#   ('ใช้', 'VACT', 'transitiveverb'),
#   ('เวลา', 'NCMN', 'noun'),
#   ('หลบหนี', 'VATT', 'transitiveverb'),
#   ('ไป', 'XVAE', 'wordafterverb'),
#   ('ตาม', 'RPRE', 'Prepositions'),
#   ('เส้นทาง', 'NCMN', 'noun'),
#   ('ต่างๆ', 'DIAC', 'Adverbs'),
#   ('ถึง', 'RPRE', 'O'),
#   ('1', 'DCNM', 'Numeralword'),
#   ('ชั่วโมง', 'CMTR', 'Qualitativenoun'),
#   ('ตลอด', 'CNIT', 'Prepositions'),
#   ('เส้นทาง', 'NCMN', 'noun'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('ประชาชน', 'NCMN', 'noun'),
#   ('ตำรวจ', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('อาสาสมัคร', 'NCMN', 'noun'),
#   ('ร่วม', 'ADVN', 'transitiveverb'),
#   ('ติดตาม', 'VACT', 'transitiveverb'),
#   ('ตำรวจ', 'RPRE', 'noun'),
#   ('นครบาล', 'NCMN', 'noun'),
#   ('บาง', 'DIBQ', 'noun'),
#   ('ซื่อ', 'JSBR', 'noun'),
#   ('เข้า', 'RPRE', 'wordbeforeverb'),
#   ('สกัดกั้น', 'NCMN', 'transitiveverb'),
#   ('โดย', 'JSBR', 'O'),
#   ('จอด', 'VACT', 'transitiveverb'),
#   ('รถจักรยานยนต์', 'NCMN', 'noun'),
#   ('ขวางหน้า', 'NCMN', 'Adverbs'),
#   ('รถ', 'NCMN', 'noun'),
#   ('เบนซ์', 'VACT', 'noun'),
#   ('เอาไว้', 'XVAE', 'O'),
#   ('แล้ว', 'XVAE', 'O'),
#   ('ให้', 'JSBR', 'transitiveverb'),
#   ('คนขับ', 'NCMN', 'noun'),
#   ('ลง', 'XVAE', 'transitiveverb'),
#   ('จาก', 'RPRE', 'Prepositions'),
#   ('รถ', 'NCMN', 'noun'),
#   ('แต่', 'JCRG', 'SSConjunctions'),
#   ('คนขับ', 'NCMN', 'noun'),
#   ('พยายาม', 'VACT', 'wordbeforeverb'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('ดัน', 'VACT', 'transitiveverb'),
#   ('รถจักรยานยนต์', 'NCMN', 'noun'),
#   ('ตำรวจ', 'NCMN', 'noun'),
#   ('เพื่อ', 'JSBR', 'SSConjunctions'),
#   ('เปิด', 'VACT', 'transitiveverb'),
#   ('ทาง', 'NCMN', 'noun'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('หลบหนี', 'NCMN', 'transitiveverb'),
#   ('ต่อ', 'RPRE', 'O'),
#   ('โดย', 'RPRE', 'O'),
#   ('ยัง', 'XVBM', 'wordbeforeverb'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('หลบหนี', 'NCMN', 'transitiveverb'),
#   ('ต่อเนื่อง', 'VSTA', 'Adverbs'),
#   ('ไป', 'XVAE', 'wordafterverb'),
#   ('ตาม', 'RPRE', 'Prepositions'),
#   ('ท้องถนน', 'NCMN', 'noun'),
#   ('ท้ายที่สุด', 'ADVN', 'O'),
#   ('ตำรวจ', 'ADVN', 'noun'),
#   ('ติดตาม', 'VACT', 'transitiveverb'),
#   ('สกัด', 'VACT', 'transitiveverb'),
#   ('ให้', 'JSBR', 'wordbeforeverb'),
#   ('หยุด', 'VSTA', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('ได้', 'XVAE', 'wordafterverb'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('ย่าน', 'NCMN', 'noun'),
#   ('เตา', 'NCMN', 'noun'),
#   ('ปูน', 'NCMN', 'noun'),
#   ('โดย', 'RPRE', 'O'),
#   ('คนขับรถ', 'NCMN', 'noun'),
#   ('เบนซ์', 'NCMN', 'noun'),
#   ('ยอม', 'VSTA', 'wordbeforeverb'),
#   ('ลง', 'XVAE', 'noun'),
#   ('จาก', 'RPRE', 'Prepositions'),
#   ('รถ', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'O'),
#   ('พบ', 'VACT', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('ได้รับ', 'VSTA', 'wordbeforeverb'),
#   ('บาดเจ็บ', 'NCMN', 'intransitiveverb'),
#   ('เจ้าหน้าที่', 'NCMN', 'noun'),
#   ('ช่วย', 'VACT', 'wordbeforeverb'),
#   ('เกลี้ยกล่อม', 'VACT', 'transitiveverb'),
#   ('และ', 'JCRG', 'O'),
#   ('นำ', 'VACT', 'transitiveverb'),
#   ('ส่ง', 'VACT', 'transitiveverb'),
#   ('โรงพยาบาล', 'NCMN', 'noun'),
#   ('เพื่อ', 'RPRE', 'SSConjunctions'),
#   ('รักษา', 'VACT', 'transitiveverb'),
#   ('บาดแผล', 'NCMN', 'noun'),
#   ('เหตุการณ์', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('เกิดขึ้น', 'VSTA', 'transitiveverb'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('ผู้', 'PPRS', 'noun'),
#   ('ได้รับบาดเจ็บ', 'VSTA', 'noun'),
#   ('ถูก', 'XVAM', 'transitiveverb'),
#   ('เฉี่ยว', 'VACT', 'transitiveverb'),
#   ('ชน', 'VACT', 'transitiveverb'),
#   ('หลาย', 'DIBQ', 'Numeralword'),
#   ('คน', 'CNIT', 'Qualitativenoun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('รถยนต์', 'NCMN', 'noun'),
#   ('เสียหาย', 'VSTA', 'intransitiveverb')],
#  [('2', 'NLBL', 'Numeralword'),
#   ('คัน', 'CNIT', 'Qualitativenoun'),
#   ('รถจักรยานยนต์', 'NCMN', 'noun'),
#   ('เสียหาย', 'VSTA', 'intransitiveverb'),
#   ('4', 'DCNM', 'Numeralword'),
#   ('คัน', 'CNIT', 'Qualitativenoun'),
#   ('ตำรวจ', 'NCMN', 'noun'),
#   ('ตรวจ', 'VACT', 'transitiveverb'),
#   ('ร่างกาย', 'NCMN', 'noun'),
#   ('คนขับรถ', 'NCMN', 'noun'),
#   ('เบนซ์', 'NCMN', 'noun'),
#   ('พบ', 'VSTA', 'transitiveverb'),
#   ('ปริมาณ', 'NCMN', 'noun'),
#   ('แอลกอฮอล์', 'NCMN', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('เลือด', 'NCMN', 'noun'),
#   ('257', 'DCNM', 'Numeralword'),
#   ('มิลลิกรัม', 'CMTR', 'Qualitativenoun'),
#   ('เปอร์เซ็นต์', 'CMTR', 'Qualitativenoun'),
#   ('ซึ่ง', 'JSBR', 'SSConjunctions'),
#   ('เกิน', 'ADVN', 'Adverbs'),
#   ('กว่า', 'JCMP', 'Adverbs'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('กฎหมาย', 'NCMN', 'noun'),
#   ('กำหนด', 'VACT', 'intransitiveverb')],
#  [('วันนี้', 'NCMN', 'Pronouns'),
#   ('(', 'PUNC', 'O'),
#   ('12', 'NCNM', 'Numeralword'),
#   ('ส.ค.', 'NCMN', 'abbreviation'),
#   ('2563', 'NCNM', 'Numeralword'),
#   (')', 'PUNC', 'O'),
#   ('เวลา', 'NCMN', 'Timeexpressionword'),
#   ('ประมาณ', 'DIBQ', 'wordbeforenumeral'),
#   ('00.30', 'DCNM', 'Numeralword'),
#   ('น.', 'CNIT', 'abbreviation'),
#   ('ผู้สื่อข่าว', 'DDAC', 'noun'),
#   ('รายงาน', 'VACT', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('เกิดเหตุ', 'NCMN', 'transitiveverb'),
#   ('หญิง', 'NCMN', 'noun'),
#   ('เมา', 'NCMN', 'intransitiveverb'),
#   ('แล้ว', 'XVAE', 'wordafterverb'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('รถยนต์', 'NCMN', 'noun'),
#   ('เบนซ์', 'NCMN', 'noun'),
#   ('เฉี่ยว', 'VATT', 'transitiveverb'),
#   ('ชน', 'NCMN', 'transitiveverb'),
#   ('ยานพาหนะ', 'VACT', 'noun'),
#   ('ผู้อื่น', 'NCMN', 'noun'),
#   ('เสียหาย', 'VSTA', 'intransitiveverb'),
#   ('หลาย', 'DIBQ', 'Numeralword'),
#   ('คัน', 'CNIT', 'Qualitativenoun'),
#   ('แต่', 'JCRG', 'NounConjunctions'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('หลบหนี', 'NCMN', 'transitiveverb'),
#   ('ประชาชน', 'NCMN', 'noun'),
#   ('หลาย', 'DIBQ', 'Numeralword'),
#   ('คน', 'CNIT', 'Qualitativenoun'),
#   ('จึง', 'XVBM', 'wordbeforeverb'),
#   ('ช่วย', 'VACT', 'transitiveverb'),
#   ('ตำรวจจราจร', 'VACT', 'noun'),
#   ('ขี่', 'NCMN', 'transitiveverb'),
#   ('รถจักรยานยนต์', 'NCMN', 'noun'),
#   ('ไล่', 'VACT', 'transitiveverb'),
#   ('ติดตาม', 'VACT', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('เบนซ์', 'NCMN', 'noun'),
#   ('โดย', 'RPRE', 'O'),
#   ('รถ', 'NCMN', 'noun'),
#   ('คัน', 'CNIT', 'Pronouns'),
#   ('ดังกล่าว', 'DDAC', 'Pronouns'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('มา', 'XVAE', 'transitiveverb'),
#   ('จาก', 'RPRE', 'Prepositions'),
#   ('ย่าน', 'NCMN', 'noun'),
#   ('แค', 'NCMN', 'noun'),
#   ('ราย', 'CNIT', 'noun'),
#   ('อ.', 'NCMN', 'abbreviation'),
#   ('เมือง', 'VSTA', 'noun'),
#   ('นนทบุรี', 'NCMN', 'noun'),
#   ('ต่อเนื่อง', 'VSTA', 'Prepositions'),
#   ('บาง', 'DIBQ', 'noun'),
#   ('ซื่อ', 'JSBR', 'noun'),
#   ('-', 'PUNC', 'noun'),
#   ('ถ.', 'NCMN', 'noun'),
#   ('พหลโยธิน', 'NCMN', 'noun'),
#   ('ขณะที่', 'JSBR', 'SSConjunctions'),
#   ('รถ', 'VACT', 'noun'),
#   ('เบนซ์', 'NCMN', 'noun'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('มา', 'XVAE', 'transitiveverb'),
#   ('ถึง', 'RPRE', 'transitiveverb'),
#   ('ย่าน', 'NCMN', 'noun'),
#   ('สะพาน', 'NCMN', 'noun'),
#   ('ควาย', 'NCMN', 'noun'),
#   ('ตำรวจจราจร', 'NCMN', 'noun'),
#   ('สน.', 'NCMN', 'abbreviation'),
#   ('บาง', 'DIBQ', 'noun'),
#   ('ซื่อ', 'JSBR', 'noun'),
#   ('เข้า', 'RPRE', 'wordbeforeverb'),
#   ('สกัดกั้น', 'NCMN', 'transitiveverb'),
#   ('ก็', 'JSBR', 'wordbeforeverb'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('สามารถ', 'XVAM', 'wordbeforeverb'),
#   ('หยุด', 'VACT', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('เบนซ์', 'VACT', 'noun'),
#   ('ไว้', 'XVAE', 'wordafterverb'),
#   ('ได้', 'XVAE', 'wordafterverb'),
#   ('โดย', 'JSBR', 'O'),
#   ('ยัง', 'XVBM', 'wordbeforeverb'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('หลบหนี', 'NCMN', 'transitiveverb'),
#   ('ต่อเนื่อง', 'VSTA', 'Adverbs'),
#   ('ไป', 'XVAE', 'wordafterverb'),
#   ('ตาม', 'RPRE', 'Prepositions'),
#   ('ท้องถนน', 'NCMN', 'noun'),
#   ('สำหรับ', 'RPRE', 'O'),
#   ('เหตุการณ์', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('เกิด', 'VSTA', 'transitiveverb'),
#   ('ขึ้น', 'XVAE', 'wordafterverb'),
#   ('[', 'NCMN', 'transitiveverb'),
#   ('PhrasalVerbs', 'NCMN', 'transitiveverb'),
#   (']', 'NCMN', 'transitiveverb'),
#   ('ส่งผล', 'VACT', 'transitiveverb'),
#   ('ให้', 'JSBR', 'transitiveverb'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('ผู้', 'PPRS', 'noun'),
#   ('ได้รับบาดเจ็บ', 'VACT', 'PhrasalVerbs'),
#   ('หลาย', 'DIBQ', 'Numeralword'),
#   ('คน', 'CNIT', 'Qualitativenoun'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('รถยนต์', 'NCMN', 'noun'),
#   ('เก๋ง', 'NCMN', 'noun'),
#   ('เสียหาย', 'VSTA', 'intransitiveverb'),
#   ('2', 'DCNM', 'Numeralword'),
#   ('คัน', 'CNIT', 'Qualitativenoun'),
#   ('รถจักรยานยนต์', 'CMTR', 'noun'),
#   ('4', 'DCNM', 'Numeralword'),
#   ('คัน', 'CNIT', 'Qualitativenoun'),
#   ('ส่วน', 'CNIT', 'O'),
#   ('คน', 'NCMN', 'noun'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('เบนซ์', 'NCMN', 'noun'),
#   ('คัน', 'NCMN', 'Qualitativenoun'),
#   ('ก่อ', 'NCMN', 'transitiveverb'),
#   ('เหตุ', 'NCMN', 'noun'),
#   ('ตำรวจ', 'NCMN', 'noun'),
#   ('ตรวจ', 'VACT', 'transitiveverb'),
#   ('ร่างกาย', 'NCMN', 'noun'),
#   ('พบ', 'VSTA', 'transitiveverb'),
#   ('ปริมาณ', 'NCMN', 'noun'),
#   ('แอลกอฮอล์', 'NCMN', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('เลือด', 'NCMN', 'noun'),
#   ('257', 'DCNM', 'Numeralword'),
#   ('มิลลิกรัม', 'NCMN', 'Qualitativenoun'),
#   ('เปอร์เซ็นต์', 'CMTR', 'Qualitativenoun'),
#   ('เกิน', 'ADVN', 'Adverbs'),
#   ('กว่า', 'JCMP', 'O'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('กฎหมาย', 'NCMN', 'noun'),
#   ('กำหนด', 'VACT', 'transitiveverb'),
#   ('เบื้องต้น', 'VATT', 'O'),
#   ('พนักงานสอบสวน', 'NCMN', 'noun'),
#   ('แจ้ง', 'NCMN', 'transitiveverb'),
#   ('4', 'NCNM', 'Numeralword'),
#   ('ข้อกล่าวหา', 'NCMN', 'noun'),
#   ('เมา', 'CNIT', 'intransitiveverb'),
#   ('แล้ว', 'XVAE', 'wordafterverb'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   (',', 'PUNC', 'O'),
#   ('ชน', 'NCMN', 'intransitiveverb'),
#   ('แล้ว', 'XVAE', 'wordafterverb'),
#   ('หนี', 'VACT', 'intransitiveverb'),
#   (',', 'PUNC', 'O'),
#   ('ขับ', 'VACT', 'transitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('ประมาท', 'NCMN', 'Adverbs'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('เหตุ', 'NCMN', 'noun'),
#   ('ทำให้', 'VACT', 'transitiveverb'),
#   ('ผู้อื่น', 'NCMN', 'noun'),
#   ('ได้รับ', 'VSTA', 'PhrasalVerbs'),
#   ('ความเสียหาย', 'NCMN', 'PhrasalVerbs'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ข้อหา', 'NCMN', 'NounConjunctions'),
#   ('ต่อสู้', 'NCMN', 'PhrasalVerbs'),
#   ('ขัดขวาง', 'VACT', 'PhrasalVerbs'),
#   ('เจ้าพนักงาน', 'NCMN', 'noun'),
#   ('พร้อม', 'VSTA', 'O'),
#   ('คัดค้าน', 'NCMN', 'transitiveverb'),
#   ('การ', 'FIXN', 'noun'),
#   ('ประกันตัว', 'VACT', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('ชั้น', 'NCMN', 'noun'),
#   ('พนักงานสอบสวน', 'NCMN', 'noun'),
#   ('เนื่องจาก', 'JSBR', 'O'),
#   ('เกรง', 'VSTA', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'transitiveverb'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('หลบหนี', 'VACT', 'intransitiveverb')],
#  [('วัน', 'NCMN', 'Timeexpressionword'),
#   ('นี้', 'DDAC', 'Pronouns'),
#   ('(', 'PUNC', 'O'),
#   ('11', 'NCNM', 'Numeralword'),
#   ('ส.ค.', 'NCMN', 'abbreviation'),
#   ('2563', 'NCNM', 'Numeralword'),
#   (')', 'PUNC', 'O'),
#   ('ตำรวจ', 'NCMN', 'noun'),
#   ('สืบสวน', 'VACT', 'noun'),
#   ('นครบาล', 'NCMN', 'noun'),
#   ('ท่าข้าม', 'NCMN', 'noun'),
#   ('พร้อม', 'VSTA', 'NounConjunctions'),
#   ('ชุด', 'CLTV', 'noun'),
#   ('สืบสวน', 'NCMN', 'noun'),
#   ('กอง', 'NCMN', 'noun'),
#   ('บังคับการ', 'NCMN', 'noun'),
#   ('ตำรวจนครบาล', 'NCMN', 'noun'),
#   ('[', 'NCMN', 'noun'),
#   ('noun', 'NCMN', 'noun'),
#   ('][', 'NCMN', 'noun'),
#   ('Numeralword', 'NCMN', 'noun'),
#   (']', 'NCMN', 'noun'),
#   ('9', 'NCNM', 'noun'),
#   ('ร่วม', 'VSTA', 'transitiveverb'),
#   ('กัน', 'ADVN', 'wordafterverb'),
#   ('จับกุม', 'ADVN', 'transitiveverb'),
#   ('ชาย', 'NCMN', 'noun'),
#   ('อายุ', 'NCMN', 'noun'),
#   ('34', 'DCNM', 'Numeralword'),
#   ('ปี', 'CMTR', 'Qualitativenoun'),
#   ('อาชีพ', 'CMTR', 'noun'),
#   ('พ่อค้า', 'NCMN', 'noun'),
#   ('ขาย', 'VACT', 'transitiveverb'),
#   ('ปลาหมึก', 'NCMN', 'noun'),
#   ('ย่าง', 'VATT', 'noun'),
#   ('[', 'NCMN', 'noun'),
#   ('noun', 'NCMN', 'noun'),
#   ('][', 'NCMN', 'noun'),
#   ('SSConjunctions', 'NCMN', 'noun'),
#   (']', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'noun'),
#   ('ก่อ', 'VACT', 'transitiveverb'),
#   ('เหตุ', 'NCMN', 'noun'),
#   ('ชิง', 'NCMN', 'transitiveverb'),
#   ('เงิน', 'NCMN', 'noun'),
#   ('90,000', 'DCNM', 'Numeralword'),
#   ('บาท', 'CMTR', 'Qualitativenoun'),
#   ('จาก', 'RPRE', 'Prepositions'),
#   ('ห้าง', 'NCMN', 'noun'),
#   ('เพชร', 'NCMN', 'noun'),
#   ('ทองใบ', 'NCMN', 'noun'),
#   ('เยาวราช', 'VACT', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('ห้างสรรพสินค้า', 'NCMN', 'noun'),
#   ('โลตัส', 'NCMN', 'noun'),
#   ('พระราม', 'NCMN', 'noun'),
#   ('2', 'NCNM', 'Numeralword'),
#   ('เมื่อ', 'JSBR', 'SSConjunctions'),
#   ('ช่วง', 'NCMN', 'Timeexpressionword'),
#   ('เย็น', 'VATT', 'Timeexpressionword'),
#   ('วาน', 'NCMN', 'Timeexpressionword'),
#   ('นี้', 'DDAC', 'Pronouns'),
#   ('พ.ต.อ.', 'NCMN', 'wordbeforenoun'),
#   ('นครินทร์', 'DDAC', 'noun'),
#   ('สุคนธ', 'NCMN', 'noun'),
#   ('วิ', 'NCMN', 'noun'),
#   ('ท', 'NCMN', 'noun'),
#   ('รอง', 'VATT', 'noun'),
#   ('ผู้บังคับการ', 'NCMN', 'noun'),
#   ('ตำรวจนครบาล', 'VACT', 'noun'),
#   ('9', 'NCNM', 'Numeralword'),
#   ('เปิดเผย', 'VSTA', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('จาก', 'RPRE', 'Prepositions'),
#   ('การ', 'FIXN', 'noun'),
#   ('สอบสวน', 'VACT', 'noun'),
#   ('ผู้ต้องหา', 'NCMN', 'noun'),
#   ('เบื้องต้น', 'VATT', 'O'),
#   ('รับสารภาพ', 'VSTA', 'intransitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('ผู้ก่อเหตุ', 'NCMN', 'noun'),
#   ('โดย', 'JSBR', 'O'),
#   ('ทำ', 'VACT', 'transitiveverb'),
#   ('ไป', 'XVAE', 'transitiveverb'),
#   ('เพราะ', 'JSBR', 'O'),
#   ('เหตุ', 'NCMN', 'noun'),
#   ('ซึ่ง', 'PREL', 'Prepositions'),
#   ('หน้า', 'VATT', 'noun'),
#   ('เนื่องจาก', 'JSBR', 'SSConjunctions'),
#   ('ไป', 'XVAE', 'wordbeforeverb'),
#   ('รับประทาน', 'VACT', 'transitiveverb'),
#   ('อาหาร', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('[', 'VACT', 'Prepositions'),
#   ('Prepositions', 'NCMN', 'Prepositions'),
#   ('][', 'NCMN', 'Prepositions'),
#   ('noun', 'NCMN', 'Prepositions'),
#   (']', 'NCMN', 'Prepositions'),
#   ('ห้างสรรพสินค้า', 'NCMN', 'Prepositions'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('เกิด', 'VSTA', 'transitiveverb'),
#   ('เหตุ', 'NCMN', 'noun'),
#   ('ก่อน', 'RPRE', 'wordbeforeverb'),
#   ('พบ', 'VACT', 'transitiveverb'),
#   ('พนักงาน', 'NCMN', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('ร้าน', 'NCMN', 'noun'),
#   ('กำลัง', 'XVBM', 'wordbeforeverb'),
#   ('นับ', 'VACT', 'transitiveverb'),
#   ('เงิน', 'NCMN', 'noun'),
#   ('จึง', 'XVBM', 'wordbeforeverb'),
#   ('คว้า', 'VACT', 'transitiveverb'),
#   ('เงิน', 'NCMN', 'noun'),
#   ('จาก', 'RPRE', 'Prepositions'),
#   ('มือ', 'NCMN', 'noun'),
#   ('พนักงาน', 'NCMN', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('ร้าน', 'NCMN', 'noun'),
#   ('จากนั้น', 'JSBR', 'O'),
#   ('ได้', 'XVAM', 'wordbeforeverb'),
#   ('วิ่ง', 'VACT', 'intransitiveverb'),
#   ('ออก', 'XVAE', 'wordafterverb'),
#   ('จาก', 'RPRE', 'Prepositions'),
#   ('ห้าง', 'NCMN', 'noun'),
#   ('มา', 'XVAE', 'wordbeforeverb'),
#   ('ขึ้น', 'XVAE', 'transitiveverb'),
#   ('รถแท็กซี่', 'NCMN', 'noun'),
#   ('ไป', 'XVAE', 'wordbeforeverb'),
#   ('ซื้อ', 'VACT', 'transitiveverb'),
#   ('เสื้อผ้า', 'NCMN', 'noun'),
#   ('เปลี่ยน', 'VACT', 'intransitiveverb'),
#   ('ย่าน', 'NCMN', 'noun'),
#   ('สะแกงาม', 'NCMN', 'noun'),
#   ('จากนั้น', 'JSBR', 'O'),
#   ('ได้', 'XVAM', 'wordbeforeverb'),
#   ('นั่ง', 'VACT', 'intransitiveverb'),
#   ('รถ', 'NCMN', 'noun'),
#   ('ต่อ', 'RPRE', 'wordafterverb'),
#   ('ไป', 'XVAE', 'transitiveverb'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('จ.', 'NCMN', 'abbreviation'),
#   ('ปทุมธานี', 'NCMN', 'noun'),
#   ('เพื่อ', 'JSBR', 'O'),
#   ('หลบหนี', 'VACT', 'intransitiveverb'),
#   ('ไป', 'XVAE', 'wordbeforeverb'),
#   ('อยู่', 'XVAE', 'transitiveverb'),
#   ('ที่', 'RPRE', 'Prepositions'),
#   ('บ้าน', 'NCMN', 'noun'),
#   ('เพื่อน', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ไป', 'VACT', 'wordbeforeverb'),
#   ('ดื่ม', 'VACT', 'transitiveverb'),
#   ('สุรา', 'NCMN', 'noun'),
#   ('อยู่', 'XVAE', 'wordafterverb'),
#   ('กับ', 'RPRE', 'Prepositions'),
#   ('กลุ่ม', 'NCMN', 'noun'),
#   ('เพื่อน', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ช่วง', 'NCMN', 'Timeexpressionword'),
#   ('เช้า', 'VATT', 'Timeexpressionword'),
#   ('ที่ผ่านมา', 'ADVN', 'Timeexpressionword'),
#   ('ผู้ต้องหา', 'NCMN', 'noun'),
#   ('ได้', 'XVAE', 'wordbeforeverb'),
#   ('มา', 'XVAE', 'transitiveverb'),
#   ('ฟอก', 'VACT', 'transitiveverb'),
#   ('ไต', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('คลินิก', 'NCMN', 'noun'),
#   ('ย่าน', 'NCMN', 'noun'),
#   ('บาง', 'DIBQ', 'noun'),
#   ('ขุน', 'NCMN', 'noun'),
#   ('เทียน', 'NCMN', 'noun'),
#   ('ตำรวจ', 'NCMN', 'noun'),
#   ('จึง', 'XVBM', 'wordbeforeverb'),
#   ('เข้า', 'VACT', 'transitiveverb'),
#   ('ไป', 'XVAE', 'wordafterverb'),
#   ('แสดง', 'VACT', 'transitiveverb'),
#   ('ตัว', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('จับ', 'NCMN', 'transitiveverb'),
#   ('ผู้ต้องหา', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('พบ', 'VSTA', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('เงิน', 'NCMN', 'noun'),
#   ('ติด', 'VSTA', 'transitiveverb'),
#   ('ตัว', 'NCMN', 'noun'),
#   ('เหลือ', 'VSTA', 'wordbeforenumeral'),
#   ('15,000', 'DCNM', 'Numeralword'),
#   ('บาท', 'CMTR', 'Qualitativenoun')],
#  [('วัน', 'NCMN', 'Timeexpressionword'),
#   ('นี้', 'DDAC', 'Pronouns'),
#   ('(', 'PUNC', 'O'),
#   ('11', 'NCNM', 'Numeralword'),
#   ('ส.ค.', 'NCMN', 'abbreviation'),
#   ('2563', 'NCNM', 'Numeralword'),
#   (')', 'PUNC', 'O'),
#   ('น.ส.', 'NTTL', 'wordbeforenoun'),
#   ('สิ', 'NPRP', 'noun'),
#   ('ตา', 'NCMN', 'noun'),
#   ('นัน', 'NCMN', 'noun'),
#   ('สัตย์', 'NCMN', 'noun'),
#   ('ศักดิ์สิทธิ์', 'NCMN', 'noun'),
#   ('พี่สาว', 'NCMN', 'Pronouns'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('นาย', 'NCMN', 'wordbeforenoun'),
#   ('วัน', 'NCMN', 'noun'),
#   ('เฉลิม', 'DIAC', 'noun'),
#   ('สัตย์', 'NCMN', 'noun'),
#   ('ศักดิ์สิทธิ์', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('แอม', 'NCMN', 'noun'),
#   ('เนสตี้', 'VATT', 'noun'),
#   ('อินเตอร์เนชั่นแนล', 'NCMN', 'noun'),
#   ('ประเทศ', 'NCMN', 'noun'),
#   ('ไทย', 'NPRP', 'noun'),
#   ('จัด', 'VACT', 'transitiveverb'),
#   ('กิจกรรม', 'NCMN', 'noun'),
#   ('ร้องเพลง', 'NCMN', 'intransitiveverb'),
#   ('แฮปปี้เบิร์ดเดย์', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'O'),
#   ('เป่า', 'VACT', 'transitiveverb'),
#   ('เค้ก', 'NCMN', 'noun'),
#   ('เนื่องใน', 'NCMN', 'O'),
#   ('วัน', 'NCMN', 'Timeexpressionword'),
#   ('คล้าย', 'VSTA', 'Adverbs'),
#   ('วันเกิด', 'NCMN', 'noun'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('นาย', 'NCMN', 'wordbeforenoun'),
#   ('วัน', 'NCMN', 'noun'),
#   ('เฉลิม', 'DIAC', 'noun'),
#   ('สัตย์', 'NCMN', 'noun'),
#   ('ศักดิ์สิทธิ์', 'NPRP', 'noun'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('บริเวณ', 'NCMN', 'noun'),
#   ('หน้า', 'NCMN', 'Prepositions'),
#   ('สถานเอกอัครราชทูต', 'NCMN', 'noun'),
#   ('ราชอาณาจักร', 'NCMN', 'noun'),
#   ('กัมพูชา', 'NCMN', 'noun'),
#   ('ประจำ', 'VATT', 'noun'),
#   ('ประเทศ', 'NCMN', 'noun'),
#   ('ไทย', 'NPRP', 'noun'),
#   ('พร้อมกับ', 'RPRE', 'O'),
#   ('แจก', 'NCMN', 'transitiveverb'),
#   ('เค้ก', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('คุกกี้', 'NCMN', 'noun'),
#   ('ให้', 'JSBR', 'transitiveverb'),
#   ('กับ', 'RPRE', 'wordafterverb'),
#   ('เจ้าหน้าที่ตำรวจ', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('มา', 'VACT', 'wordbeforeverb'),
#   ('ปฏิบัติ', 'VACT', 'transitiveverb'),
#   ('หน้าที่', 'NCMN', 'noun'),
#   ('อยู่', 'XVAE', 'Prepositions'),
#   ('บริเวณ', 'NCMN', 'noun'),
#   ('สถานทูต', 'NCMN', 'noun'),
#   ('ฯ', 'PUNC', 'noun')],
#  [('น.ส.', 'NTTL', 'wordbeforenoun'),
#   ('ปิย', 'NPRP', 'noun'),
#   ('นุช', 'NCMN', 'noun'),
#   ('โต', 'VATT', 'noun'),
#   ('คร', 'NCMN', 'noun'),
#   ('สาร', 'NCMN', 'noun'),
#   ('ผู้อำนวยการ', 'NCMN', 'noun'),
#   ('แอม', 'VACT', 'noun'),
#   ('เนสตี้ฯ', 'NCMN', 'noun'),
#   ('เรียกร้อง', 'NCMN', 'transitiveverb'),
#   ('ให้', 'JSBR', 'transitiveverb'),
#   ('ทางการ', 'VACT', 'noun'),
#   ('กัมพูชา', 'NCMN', 'noun'),
#   ('เร่ง', 'VACT', 'wordbeforeverb'),
#   ('ติดตาม', 'VACT', 'transitiveverb'),
#   ('หา', 'VACT', 'transitiveverb'),
#   ('ตัว', 'NCMN', 'noun'),
#   ('นาย', 'NTTL', 'wordbeforenoun'),
#   ('วัน', 'NCMN', 'noun'),
#   ('เฉลิม', 'DIAC', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('หายตัว', 'VSTA', 'intransitiveverb'),
#   ('ไป', 'XVAE', 'intransitiveverb'),
#   ('กว่า', 'JCMP', 'wordbeforenumeral'),
#   ('2', 'NCNM', 'Numeralword'),
#   ('เดือน', 'NCMN', 'Timeexpressionword'),
#   ('และ', 'JCRG', 'O'),
#   ('นำ', 'VACT', 'transitiveverb'),
#   ('ตัว', 'NCMN', 'noun'),
#   ('ผู้ต้องสงสัย', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('ก่อ', 'VACT', 'transitiveverb'),
#   ('เหตุ', 'NCMN', 'noun'),
#   ('ครั้ง', 'CFQC', 'Timeexpressionword'),
#   ('นี้', 'DDAC', 'Timeexpressionword'),
#   ('มา', 'XVAE', 'transitiveverb'),
#   ('ดำเนิน', 'VACT', 'transitiveverb'),
#   ('คดี', 'NCMN', 'noun'),
#   ('พร้อม', 'VSTA', 'O'),
#   ('เรียกร้อง', 'NCMN', 'transitiveverb'),
#   ('ให้', 'JSBR', 'wordbeforeverb'),
#   ('ปฏิบัติ', 'VACT', 'transitiveverb'),
#   ('ตาม', 'RPRE', 'Adverbs'),
#   ('ข้อกำหนด', 'NCMN', 'noun'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('อนุสัญญา', 'NCMN', 'noun'),
#   ('ระหว่าง', 'RPRE', 'Prepositions'),
#   ('ประเทศ', 'NCMN', 'noun'),
#   ('ว่าด้วย', 'RPRE', 'O'),
#   ('การ', 'FIXN', 'noun'),
#   ('คุ้มครอง', 'VACT', 'noun'),
#   ('มิ', 'NEG', 'Negator'),
#   ('ให้', 'RPRE', 'wordbeforeverb'),
#   ('บุคคล', 'NCMN', 'noun'),
#   ('สูญหาย', 'VSTA', 'intransitiveverb'),
#   ('ซึ่ง', 'PREL', 'SSConjunctions'),
#   ('กัมพูชา', 'VSTA', 'noun'),
#   ('อยู่', 'XVAE', 'transitiveverb'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('ภาคี', 'NCMN', 'noun'),
#   ('ดังกล่าว', 'DDAN', 'O'),
#   ('ด้วย', 'RPRE', 'O'),
#   ('ขณะเดียวกัน', 'JCRG', 'O'),
#   ('ได้', 'XVAM', 'wordbeforeverb'),
#   ('เชิญชวน', 'VACT', 'transitiveverb'),
#   ('ให้', 'JSBR', 'O'),
#   ('สมาชิก', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ผู้สนับสนุน', 'NCMN', 'noun'),
#   ('ร่วม', 'ADVN', 'transitiveverb'),
#   ('กัน', 'ADVN', 'wordafterverb'),
#   ('ลงชื่อ', 'JSBR', 'transitiveverb'),
#   ('เพื่อ', 'JSBR', 'SSConjunctions'),
#   ('เรียกร้อง', 'VACT', 'transitiveverb'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('กรณี', 'NCMN', 'noun'),
#   ('ดังกล่าว', 'DDAC', 'O'),
#   ('กว่า', 'JCMP', 'wordbeforenumeral'),
#   ('5,000', 'DCNM', 'Numeralword'),
#   ('รายชื่อ', 'NCMN', 'Qualitativenoun'),
#   ('เพื่อ', 'JSBR', 'O'),
#   ('ส่ง', 'VACT', 'transitiveverb'),
#   ('ให้', 'RPRE', 'transitiveverb'),
#   ('ทางการ', 'NCMN', 'noun'),
#   ('กัมพูชา', 'NCMN', 'noun'),
#   ('เร่ง', 'VACT', 'wordbeforeverb'),
#   ('สืบสวน', 'NCMN', 'transitiveverb'),
#   ('เรื่อง', 'NCMN', 'noun'),
#   ('นี้', 'DDAC', 'Pronouns'),
#   ('อย่าง', 'FIXV', 'O'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('ประสิทธิภาพ', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'O'),
#   ('คืน', 'NCMN', 'transitiveverb'),
#   ('ความยุติธรรม', 'NCMN', 'noun'),
#   ('ให้', 'JSBR', 'O'),
#   ('กับ', 'RPRE', 'Prepositions'),
#   ('ครอบครัว', 'NCMN', 'noun'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('นาย', 'NCMN', 'wordbeforenoun'),
#   ('วัน', 'NCMN', 'noun'),
#   ('เฉลิม', 'DIAC', 'noun'),
#   ('ขณะที่', 'JSBR', 'O'),
#   ('น.ส.', 'NTTL', 'wordbeforenoun'),
#   ('สิ', 'NPRP', 'noun'),
#   ('ตา', 'NCMN', 'noun'),
#   ('นัน', 'NCMN', 'noun'),
#   ('พี่สาว', 'NCMN', 'Pronouns'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('นาย', 'NCMN', 'wordbeforenoun'),
#   ('วัน', 'NCMN', 'noun'),
#   ('เฉลิม', 'DIAC', 'noun'),
#   ('กล่าว', 'VACT', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('ทาง', 'RPRE', 'noun'),
#   ('ครอบครัว', 'NCMN', 'noun'),
#   ('ยัง', 'XVBM', 'wordbeforeverb'),
#   ('รอ', 'VSTA', 'transitiveverb'),
#   ('ความคืบหน้า', 'NCMN', 'noun'),
#   ('ทาง', 'NCMN', 'noun'),
#   ('คดี', 'NCMN', 'noun'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('ทางการ', 'NCMN', 'noun'),
#   ('กัมพูชา', 'NCMN', 'noun'),
#   ('แม้ว่า', 'JSBR', 'O'),
#   ('ได้', 'XVAM', 'wordbeforeverb'),
#   ('แต่งตั้ง', 'VACT', 'transitiveverb'),
#   ('ทนาย', 'NCMN', 'noun'),
#   ('ให้', 'JSBR', 'wordbeforeverb'),
#   ('ไป', 'VACT', 'wordbeforeverb'),
# ...
#   ('เวลา', 'NCMN', 'SSConjunctions'),
#   ('08.00', 'NCNM', 'Numeralword'),
#   ('น.', 'CMTR', 'abbreviation'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('วัน', 'NCMN', 'Timeexpressionword'),
#   ('นี้', 'DDAC', 'Pronouns'),
#   ('ผู้สื่อข่าว', 'NCMN', 'noun'),
#   ('ได้', 'XVAE', 'PhrasalVerbs'),
#   ('ลง', 'VACT', 'PhrasalVerbs'),
#   ('พื้นที่', 'NCMN', 'PhrasalVerbs'),
#   ('หมู่บ้าน', 'NCMN', 'noun'),
#   ('หนึ่ง', 'DCNM', 'Numeralword'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('ต.', 'NCMN', 'abbreviation'),
#   ('ภู', 'NCMN', 'noun'),
#   ('ปอ', 'NCMN', 'noun'),
#   ('อ.', 'NCMN', 'abbreviation'),
#   ('เมือง', 'VSTA', 'noun'),
#   ('จ.', 'NCMN', 'abbreviation'),
#   ('กาฬสินธุ์', 'NCMN', 'noun'),
#   ('ซึ่ง', 'PREL', 'SSConjunctions'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('บ้าน', 'NCMN', 'Nounphrase'),
#   ('ของ', 'RPRE', 'Nounphrase'),
#   ('ยาย', 'NCMN', 'Nounphrase'),
#   ('เด็กหญิง', 'NCMN', 'Nounphrase'),
#   ('วัย', 'NCMN', 'Nounphrase'),
#   ('8', 'NCNM', 'Numeralword'),
#   ('ขวบ', 'NCMN', 'Qualitativenoun'),
#   ('พบ', 'VSTA', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('ญาติ', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('เพื่อนบ้าน', 'NCMN', 'noun'),
#   ('ต่าง', 'VSTA', 'Adverbs'),
#   ('พา', 'VACT', 'transitiveverb'),
#   ('กัน', 'ADVN', 'Adverbs'),
#   ('นั่ง', 'RPRE', 'PhrasalVerbs'),
#   ('พูดคุย', 'NCMN', 'PhrasalVerbs'),
#   ('วิพากษ์วิจารณ์', 'NCMN', 'PhrasalVerbs'),
#   ('เรื่องราว', 'NCMN', 'Nounphrase'),
#   ('ที่', 'PREL', 'Nounphrase'),
#   ('เกิดขึ้น', 'VSTA', 'Nounphrase'),
#   ('พร้อมกับ', 'RPRE', 'NounConjunctions'),
#   ('พา', 'NCMN', 'PhrasalVerbs'),
#   ('ไปดู', 'NCMN', 'PhrasalVerbs'),
#   ('จุด', 'NCMN', 'noun'),
#   ('เกิดเหตุ', 'NCMN', 'noun'),
#   ('บริเวณ', 'NCMN', 'Nounphrase'),
#   ('ศูนย์', 'NCMN', 'Nounphrase'),
#   ('ทอผ้า', 'NCMN', 'Nounphrase'),
#   ('ชุมชน', 'NCMN', 'Nounphrase'),
#   ('ซึ่ง', 'PREL', 'SSConjunctions'),
#   ('อยู่', 'VSTA', 'transitiveverb'),
#   ('กลาง', 'RPRE', 'Adjectives'),
#   ('หมู่บ้าน', 'NCMN', 'noun'),
#   ('ห่าง', 'VATT', 'Adjectives'),
#   ('จาก', 'RPRE', 'Prepositions'),
#   ('บ้าน', 'NCMN', 'Nounphrase'),
#   ('ผู้เสียหาย', 'NCMN', 'Nounphrase'),
#   ('ประมาณ', 'DIBQ', 'wordbeforenumeral'),
#   ('500', 'DCNM', 'Numeralword'),
#   ('เมตร', 'CMTR', 'Qualitativenoun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('อยู่', 'VSTA', 'transitiveverb'),
#   ('ใกล้', 'RPRE', 'Adjectives'),
#   ('กับ', 'RPRE', 'NounConjunctions'),
#   ('บ้าน', 'NCMN', 'Nounphrase'),
#   ('ของ', 'RPRE', 'Nounphrase'),
#   ('ชาย', 'NCMN', 'Nounphrase'),
#   ('อายุ', 'NCMN', 'noun'),
#   ('71', 'NCNM', 'Numeralword'),
#   ('ปี', 'CMTR', 'Qualitativenoun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('ถูก', 'XVAM', 'PhrasalVerbs'),
#   ('กล่าวหา', 'VACT', 'PhrasalVerbs')],
#  [('นาง', 'NTTL', 'wordbeforenoun'),
#   ('เอ', 'NPRP', 'noun'),
#   ('นาม', 'NCMN', 'noun'),
#   ('สมมุติ', 'NCMN', 'intransitiveverb'),
#   ('อายุ', 'NCMN', 'noun'),
#   ('48', 'DCNM', 'Numeralword'),
#   ('ปี', 'CMTR', 'Qualitativenoun'),
#   ('ยาย', 'VACT', 'Nounphrase'),
#   ('เด็กหญิง', 'NCNM', 'Nounphrase'),
#   ('วัย', 'NCMN', 'Nounphrase'),
#   ('8', 'NCNM', 'Numeralword'),
#   ('ขวบ', 'NCMN', 'Qualitativenoun'),
#   ('เปิดเผย', 'VSTA', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('วันเกิดเหตุ', 'NCMN', 'Timeexpressionword'),
#   ('ได้', 'XVAE', 'PhrasalVerbs'),
#   ('ไป', 'XVAE', 'PhrasalVerbs'),
#   ('ทอ', 'VACT', 'PhrasalVerbs'),
#   ('เสื่อ', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('ศูนย์', 'NCMN', 'Nounphrase'),
#   ('ทอผ้า', 'NCMN', 'Nounphrase'),
#   ('ชุมชน', 'NCMN', 'Nounphrase'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('อยู่', 'VSTA', 'transitiveverb'),
#   ('กลาง', 'RPRE', 'Adverbs'),
#   ('หมู่บ้าน', 'NCMN', 'noun'),
#   ('ซึ่ง', 'PREL', 'SSConjunctions'),
#   ('ห่าง', 'VSTA', 'Adverbs'),
#   ('จาก', 'RPRE', 'Prepositions'),
#   ('บ้าน', 'NCMN', 'noun'),
#   ('ประมาณ', 'DIBQ', 'wordbeforenumeral'),
#   ('500', 'DCNM', 'Numeralword'),
#   ('เมตร', 'CMTR', 'Qualitativenoun'),
#   ('ส่วน', 'CNIT', 'SSConjunctions'),
#   ('หลาน', 'NCMN', 'Pronouns'),
#   ('สาว', 'NCMN', 'Adjectives'),
#   ('ก็', 'JSBR', 'wordbeforeverb'),
#   ('วิ่งเล่น', 'VACT', 'intransitiveverb'),
#   ('กับ', 'RPRE', 'NounConjunctions'),
#   ('เพื่อน', 'NCMN', 'noun'),
#   ('อยู่', 'VSTA', 'transitiveverb'),
#   ('ข้างนอก', 'NCMN', 'Adverbs'),
#   ('กระทั่ง', 'NCMN', 'SSConjunctions'),
#   ('ได้ยิน', 'NCMN', 'transitiveverb'),
#   ('เสียง', 'NCMN', 'Nounphrase'),
#   ('ร้องไห้', 'NCMN', 'Nounphrase'),
#   ('แต่', 'JCRG', 'SSConjunctions'),
#   ('ทีแรก', 'ADVS', 'SSConjunctions'),
#   ('ก็', 'JSBR', 'wordbeforeverb'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('ได้คิด', 'VACT', 'PhrasalVerbs'),
#   ('อะไร', 'PNTR', 'Pronouns'),
#   ('นึก', 'VACT', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('เด็ก', 'NCMN', 'noun'),
#   ('ร้องไห้', 'VACT', 'PhrasalVerbs'),
#   ('หยอกล้อ', 'NCMN', 'PhrasalVerbs'),
#   ('กัน', 'ADVN', 'Adverbs'),
#   ('ตาม', 'RPRE', 'transitiveverb'),
#   ('ประสา', 'NCMN', 'Nounphrase'),
#   ('เด็ก', 'NCMN', 'Nounphrase'),
#   ('จน', 'JSBR', 'SSConjunctions'),
#   ('ต่อมา', 'ADVS', 'SSConjunctions'),
#   ('เด็ก', 'NCMN', 'noun'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('อาการ', 'NCMN', 'Nounphrase'),
#   ('ปวดท้อง', 'VATT', 'Nounphrase'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ผิดสังเกต', 'NCMN', 'PhrasalVerbs'),
#   ('ซึมเศร้า', 'NCMN', 'intransitiveverb'),
#   ('ก่อน', 'RPRE', 'SSConjunctions'),
#   ('หลาน', 'NCMN', 'Pronouns'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('เล่า', 'VACT', 'PhrasalVerbs'),
#   ('ให้', 'JSBR', 'PhrasalVerbs'),
#   ('ฟัง', 'VACT', 'PhrasalVerbs'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('ขณะ', 'JSBR', 'SSConjunctions'),
#   ('เล่น', 'VACT', 'transitiveverb'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('หมู่บ้าน', 'NCMN', 'Nounphrase'),
#   ('ผู้ก่อเหตุ', 'NCMN', 'Nounphrase'),
#   ('ซึ่ง', 'PREL', 'SSConjunctions'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('ชาย', 'NCMN', 'noun'),
#   ('อายุ', 'NCMN', 'noun'),
#   ('71', 'NCNM', 'Numeralword'),
#   ('ปี', 'CMTR', 'Qualitativenoun'),
#   ('ได้', 'XVAE', 'PhrasalVerbs'),
#   ('ชักชวน', 'VACT', 'PhrasalVerbs'),
#   ('ให้', 'JSBR', 'PhrasalVerbs'),
#   ('มา', 'VACT', 'PhrasalVerbs'),
#   ('ที่', 'PREL', 'Prepositions'),
#   ('บ้าน', 'NCMN', 'noun'),
#   ('บอก', 'VACT', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('ให้เงิน', 'VACT', 'PhrasalVerbs'),
#   ('ไป', 'XVAE', 'PhrasalVerbs'),
#   ('ซื้อ', 'VACT', 'PhrasalVerbs'),
#   ('ขนม', 'NCMN', 'noun'),
#   ('ก่อน', 'JSBR', 'SSConjunctions'),
#   ('ถูก', 'XVAM', 'PhrasalVerbs'),
#   ('ล่วงละเมิด', 'VACT', 'PhrasalVerbs'),
#   ('ทางเพศ', 'NCMN', 'noun'),
#   ('ขณะนี้', 'ADVS', 'Timeexpressionword'),
#   ('ตน', 'VACT', 'Pronouns'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ญาติ', 'NCMN', 'noun'),
#   ('ๆ', 'PUNC', 'noun'),
#   ('ยังคง', 'XVBM', 'wordbeforeverb'),
#   ('ตกใจ', 'NCMN', 'intransitiveverb'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ยัง', 'XVBM', 'wordbeforeverb'),
#   ('ยอมรับ', 'VACT', 'PhrasalVerbs'),
#   ('ทำใจไม่ได้', 'NCMN', 'PhrasalVerbs'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('เหตุการณ์', 'NCMN', 'noun'),
#   ('ดังกล่าว', 'DDAC', 'Pronouns'),
#   ('เกิดขึ้น', 'VSTA', 'PhrasalVerbs'),
#   ('กับ', 'RPRE', 'NounConjunctions'),
#   ('หลาน', 'NCMN', 'Pronouns'),
#   ('สาว', 'NCMN', 'Adjectives'),
#   ('วัย', 'NCMN', 'noun'),
#   ('เพียง', 'DDBQ', 'wordbeforenumeral'),
#   ('8', 'NCNM', 'Numeralword'),
#   ('ขวบ', 'NCMN', 'Qualitativenoun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('เชื่อ', 'VSTA', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('หลาน', 'NCMN', 'Pronouns'),
#   ('สาว', 'NCMN', 'Adjectives'),
#   ('พูด', 'VACT', 'transitiveverb'),
#   ('ความจริง', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ถูกกระทำ', 'NCMN', 'PhrasalVerbs'),
#   ('จริง', 'VATT', 'Adverbs'),
#   ('เพราะ', 'JSBR', 'SSConjunctions'),
#   ('เด็ก', 'NCMN', 'Nounphrase'),
#   ('วัย', 'NCMN', 'Nounphrase'),
#   ('นี้', 'DDAC', 'Nounphrase'),
#   ('ยัง', 'XVBM', 'wordbeforeverb'),
#   ('ไร้เดียงสา', 'VSTA', 'intransitiveverb'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('ได้', 'XVAM', 'PhrasalVerbs'),
#   ('โกหก', 'VACT', 'PhrasalVerbs'),
#   ('อย่างไรก็ตาม', 'JSBR', 'SSConjunctions'),
#   ('ตน', 'NCMN', 'Pronouns'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ญาติ', 'NCMN', 'noun'),
#   ('ยืนยัน', 'NCMN', 'transitiveverb'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('ดำเนิน', 'VACT', 'transitiveverb'),
#   ('คดี', 'NCMN', 'noun'),
#   ('กับ', 'RPRE', 'NounConjunctions'),
#   ('ผู้ก่อเหตุ', 'NCMN', 'noun'),
#   ('จนถึงที่สุด', 'ADVN', 'Adverbs')],
#  [('จากนั้น', 'JSBR', 'SSConjunctions'),
#   ('ผู้สื่อข่าว', 'NCMN', 'noun'),
#   ('ได้', 'XVAM', 'PhrasalVerbs'),
#   ('เข้า', 'VACT', 'PhrasalVerbs'),
#   ('สอบถาม', 'VACT', 'PhrasalVerbs'),
#   ('นาย', 'NTTL', 'wordbeforenoun'),
#   ('อำ', 'NPRP', 'noun'),
#   ('พร', 'NPRP', 'noun'),
#   ('พัน', 'VACT', 'noun'),
#   ('จิตร', 'NCMN', 'noun'),
#   ('อายุ', 'NCMN', 'noun'),
#   ('71', 'DCNM', 'Numeralword'),
#   ('ปี', 'CMTR', 'Qualitativenoun'),
#   ('ผู้ถูกกล่าวหา', 'NCMN', 'noun'),
#   ('ซึ่ง', 'PREL', 'SSConjunctions'),
#   ('ได้', 'XVAM', 'PhrasalVerbs'),
#   ('พา', 'VACT', 'PhrasalVerbs'),
#   ('เข้า', 'RPRE', 'PhrasalVerbs'),
#   ('ไปดู', 'NCMN', 'PhrasalVerbs'),
#   ('ภายใน', 'RPRE', 'Prepositions'),
#   ('บริเวณ', 'NCMN', 'Nounphrase'),
#   ('บ้านพัก', 'NCMN', 'Nounphrase'),
#   ('พร้อมกับ', 'JCRG', 'NounConjunctions'),
#   ('ยืนยัน', 'VACT', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('ได้', 'XVAM', 'PhrasalVerbs'),
#   ('ก่อ', 'VACT', 'PhrasalVerbs'),
#   ('เหตุ', 'NCMN', 'noun'),
#   ('ลวง', 'NCMN', 'transitiveverb'),
#   ('เด็ก', 'NCMN', 'noun'),
#   ('หญิง', 'VATT', 'Adverbs'),
#   ('เข้าไป', 'XVAE', 'PhrasalVerbs'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('บ้าน', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('กระทำ', 'VACT', 'transitiveverb'),
#   ('อนาจาร', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'SSConjunctions'),
#   ('พร้อม', 'VSTA', 'transitiveverb'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('ให้', 'VACT', 'transitiveverb'),
#   ('เจ้าหน้าที่', 'NCMN', 'noun'),
#   ('ตรวจ', 'VACT', 'transitiveverb'),
#   ('ร่างกาย', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'SSConjunctions'),
#   ('ต่อสู้', 'NCMN', 'transitiveverb'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('ทาง', 'NCMN', 'noun'),
#   ('คดี', 'NCMN', 'noun'),
#   ('เพื่อ', 'JSBR', 'SSConjunctions'),
#   ('ยืนยัน', 'VACT', 'transitiveverb'),
#   ('ความบริสุทธิ์ใจ', 'NCMN', 'noun')],
#  [('นาย', 'NTTL', 'wordbeforenoun'),
#   ('อำ', 'NPRP', 'noun'),
#   ('พร', 'NPRP', 'noun'),
#   ('พัน', 'VACT', 'noun'),
#   ('จิตร', 'NCMN', 'noun'),
#   ('อายุ', 'NCMN', 'noun'),
#   ('71', 'DCNM', 'Numeralword'),
#   ('ปี', 'CMTR', 'Qualitativenoun'),
#   ('ผู้ถูกกล่าวหา', 'CNIT', 'noun'),
#   ('กล่าว', 'VACT', 'transitiveverb'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('อาศัย', 'VSTA', 'PhrasalVerbs'),
#   ('อยู่', 'XVAE', 'PhrasalVerbs'),
#   ('บ้าน', 'NCMN', 'noun'),
#   ('หลัง', 'RPRE', 'Qualitativenoun'),
#   ('ดังกล่าว', 'DDAN', 'Pronouns'),
#   ('เพียง', 'DDBQ', 'wordbeforenumeral'),
#   ('คน', 'CNIT', 'noun'),
#   ('เดียว', 'DCNM', 'Numeralword'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('โรคประจำตัว', 'NCMN', 'noun'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('เบาหวาน', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('รับประทาน', 'NCMN', 'transitiveverb'),
#   ('ยา', 'VACT', 'noun'),
#   ('เป็น', 'VSTA', 'transitiveverb'),
#   ('ประจำ', 'VATT', 'Adverbs'),
#   ('เนื่องจาก', 'JSBR', 'SSConjunctions'),
#   ('อายุ', 'NCMN', 'noun'),
#   ('มาก', 'ADVN', 'intransitiveverb'),
#   ('แล้ว', 'XVAE', 'wordafterverb'),
#   ('ส่วน', 'NCMN', 'SSConjunctions'),
#   ('ภรรยา', 'NCMN', 'noun'),
#   ('ไป', 'XVAE', 'PhrasalVerbs'),
#   ('เลี้ยง', 'VACT', 'PhrasalVerbs'),
#   ('หลาน', 'NCMN', 'Pronouns'),
#   ('ให้', 'JSBR', 'transitiveverb'),
#   ('ลูก', 'NCMN', 'noun'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('ทำงาน', 'VACT', 'PhrasalVerbs'),
#   ('อยู่', 'XVAE', 'PhrasalVerbs'),
#   ('กรุงเทพฯ', 'NPRP', 'noun'),
#   ('ส่วน', 'NCMN', 'SSConjunctions'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('วันเกิดเหตุ', 'NCMN', 'noun'),
#   ('เวลา', 'NCMN', 'noun'),
#   ('ประมาณ', 'DIBQ', 'wordbeforenumeral'),
#   ('16.00', 'NCNM', 'Numeralword'),
#   ('น.', 'DCNM', 'abbreviation'),
#   ('ซึ่ง', 'PREL', 'SSConjunctions'),
#   ('กำลัง', 'XVBM', 'wordbeforeverb'),
#   ('ทำ', 'VACT', 'transitiveverb'),
#   ('กับข้าว', 'NCMN', 'noun'),
#   ('อยู่', 'XVAE', 'Prepositions'),
#   ('ด้านล่าง', 'NCMN', 'Adverbs'),
#   ('ของ', 'RPRE', 'NounConjunctions'),
#   ('บ้าน', 'NCMN', 'noun'),
#   ('เด็ก', 'NCMN', 'noun'),
#   ('หญิง', 'VATT', 'Adjectives'),
#   ('ได้', 'XVAE', 'PhrasalVerbs'),
#   ('เดิน', 'VACT', 'PhrasalVerbs'),
#   ('เข้ามา', 'VACT', 'PhrasalVerbs'),
#   ('เล่น', 'VACT', 'PhrasalVerbs'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('บริเวณ', 'NCMN', 'Nounphrase'),
#   ('บ้าน', 'NCMN', 'Nounphrase'),
#   ('แล้ว', 'JSBR', 'SSConjunctions'),
#   ('ขอ', 'VACT', 'transitiveverb'),
#   ('เงิน', 'NCMN', 'noun'),
#   ('ไป', 'XVAE', 'PhrasalVerbs'),
#   ('ซื้อ', 'VACT', 'PhrasalVerbs'),
#   ('ขนม', 'NCMN', 'noun'),
#   ('จึง', 'XVBM', 'SSConjunctions'),
#   ('ได้', 'XVAM', 'PhrasalVerbs'),
#   ('ให้เงิน', 'VACT', 'PhrasalVerbs'),
#   ('ไป', 'XVAE', 'PhrasalVerbs'),
#   ('20', 'DCNM', 'Numeralword'),
#   ('บาท', 'CMTR', 'Qualitativenoun'),
#   ('เพราะ', 'JSBR', 'SSConjunctions'),
#   ('เอ็นดู', 'NCMN', 'transitiveverb'),
#   ('เหมือน', 'VSTA', 'Adverbs'),
#   ('ลูกหลาน', 'NCMN', 'Nounphrase'),
#   ('แต่', 'JCRG', 'SSConjunctions'),
#   ('ยืนยัน', 'NCMN', 'PhrasalVerbs'),
#   ('ไม่', 'NEG', 'PhrasalVerbs'),
#   ('ได้', 'XVAM', 'PhrasalVerbs'),
#   ('เรียก', 'VACT', 'PhrasalVerbs'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ลวง', 'VACT', 'transitiveverb'),
#   ('เด็ก', 'NCMN', 'noun'),
#   ('หญิง', 'NCMN', 'Adverbs'),
#   ('เข้ามา', 'VACT', 'PhrasalVerbs'),
#   ('ใน', 'RPRE', 'Prepositions'),
#   ('บ้าน', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ล่วงละเมิด', 'NCMN', 'transitiveverb'),
#   ('ทางเพศ', 'NCMN', 'noun'),
#   ('ตามที่', 'JSBR', 'SSConjunctions'),
#   ('ถูก', 'XVAM', 'PhrasalVerbs'),
#   ('กล่าวหา', 'VACT', 'PhrasalVerbs'),
#   ('เพราะ', 'JSBR', 'SSConjunctions'),
#   ('อายุ', 'NCMN', 'noun'),
#   ('มาก', 'ADVN', 'intransitiveverb'),
#   ('แล้ว', 'ADVN', 'wordafterverb'),
#   ('คง', 'XVBM', 'wordbeforeverb'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('มี', 'VSTA', 'transitiveverb'),
#   ('กำลัง', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('หมด', 'NCMN', 'transitiveverb'),
#   ('สมรรถภาพ', 'NCMN', 'Nounphrase'),
#   ('ทางเพศ', 'VSTA', 'Nounphrase'),
#   ('มา', 'XVAE', 'Timeexpressionword'),
#   ('นาน', 'ADVN', 'Timeexpressionword'),
#   ('หลาย', 'DIBQ', 'Numeralword'),
#   ('ปี', 'CMTR', 'Qualitativenoun'),
#   ('แล้ว', 'JSBR', 'wordafterverb'),
#   ('อีก', 'DDBQ', 'SSConjunctions'),
#   ('ทั้ง', 'DDBQ', 'SSConjunctions'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('เคย', 'XVMM', 'wordbeforeverb'),
#   ('คิด', 'VACT', 'transitiveverb'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('ทำ', 'VACT', 'transitiveverb'),
#   ('ด้วย', 'RPRE', 'Adverbs'),
#   ('เพราะ', 'JSBR', 'SSConjunctions'),
#   ('ตนเอง', 'PDMN', 'Pronouns'),
#   ('ก็', 'JSBR', 'wordbeforeverb'),
#   ('เรียก', 'VACT', 'transitiveverb'),
#   ('เด็ก', 'ADVI', 'noun'),
#   ('ว่า', 'JSBR', 'SSConjunctions'),
#   ('หลาน', 'NCMN', 'Pronouns'),
#   ('อย่างไรก็ตาม', 'JSBR', 'SSConjunctions'),
#   ('พร้อม', 'VSTA', 'transitiveverb'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('จะ', 'XVBM', 'O'),
#   ('ยืนยัน', 'VACT', 'transitiveverb'),
#   ('ความบริสุทธิ์', 'NCMN', 'noun'),
#   ('หรือ', 'JCRG', 'NounConjunctions'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('พา', 'VACT', 'PhrasalVerbs'),
#   ('ไป', 'XVAE', 'PhrasalVerbs'),
#   ('สาบาน', 'NCMN', 'PhrasalVerbs'),
#   ('ที่ไหน', 'PNTR', 'Pronouns'),
#   ('ก็ได้', 'EAFF', 'Adjectives'),
#   ('พร้อม', 'VSTA', 'transitiveverb'),
#   ('ที่', 'PREL', 'SSConjunctions'),
#   ('จะ', 'XVBM', 'wordbeforeverb'),
#   ('ตรวจ', 'VACT', 'PhrasalVerbs'),
#   ('พิสูจน์', 'ADVN', 'PhrasalVerbs'),
#   ('ร่างกาย', 'NCMN', 'noun'),
#   ('และ', 'JCRG', 'NounConjunctions'),
#   ('ต่อสู้', 'NCMN', 'transitiveverb'),
#   ('คดี', 'NCMN', 'noun'),
#   ('เนื่องจาก', 'JSBR', 'SSConjunctions'),
#   ('ตน', 'PDMN', 'Pronouns'),
#   ('ไม่', 'NEG', 'Negator'),
#   ('ได้', 'XVAM', 'PhrasalVerbs'),
#   ('ทำ', 'VACT', 'PhrasalVerbs')]]

# %%
X_data = [extract_features(doc) for doc in datatofile] # เอา คำ แยกออกมา
y_data = [get_labels(doc) for doc in datatofile] # เอา tag แยกออกมา
X_data
# Out:
# [[{'BOS': True,
#    'postag': 'JCRG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'สิ่ง',
#    'word.nextwordisdigit': False,
#    'word.word': 'แต่'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PREL',
#    'word.nextword': 'ที่',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JCRG',
#    'word.previsspace': False,
#    'word.prevword': 'แต่',
#    'word.prevwordisdigit': False,
#    'word.word': 'สิ่ง'},
#   {'postag': 'PREL',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ชี้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'สิ่ง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ที่'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'ให้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PREL',
#    'word.previsspace': False,
#    'word.prevword': 'ที่',
#    'word.prevwordisdigit': False,
#    'word.word': 'ชี้'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'เห็น',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ชี้',
#    'word.prevwordisdigit': False,
#    'word.word': 'ให้'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'ว่า',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ให้',
#    'word.prevwordisdigit': False,
#    'word.word': 'เห็น'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NEG',
#    'word.nextword': 'มิ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'เห็น',
#    'word.prevwordisdigit': False,
#    'word.word': 'ว่า'},
#   {'postag': 'NEG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVAM',
#    'word.nextword': 'ได้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ว่า',
#    'word.prevwordisdigit': False,
#    'word.word': 'มิ'},
#   {'postag': 'XVAM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'เป็น',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NEG',
#    'word.previsspace': False,
#    'word.prevword': 'มิ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ได้'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVAE',
#    'word.nextword': 'ไป',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVAM',
#    'word.previsspace': False,
#    'word.prevword': 'ได้',
#    'word.prevwordisdigit': False,
#    'word.word': 'เป็น'},
#   {'postag': 'XVAE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ตาม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'เป็น',
#    'word.prevwordisdigit': False,
#    'word.word': 'ไป'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ครรลอง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVAE',
#    'word.previsspace': False,
#    'word.prevword': 'ไป',
#    'word.prevwordisdigit': False,
#    'word.word': 'ตาม'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ระบอบ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ตาม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ครรลอง'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ประชาธิปไตย',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ครรลอง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ระบอบ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JCRG',
#    'word.nextword': 'และ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ระบอบ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ประชาธิปไตย'},
#   {'postag': 'JCRG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'กระบวนการ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ประชาธิปไตย',
#    'word.prevwordisdigit': False,
#    'word.word': 'และ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'รัฐธรรมนูญ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JCRG',
#    'word.previsspace': False,
#    'word.prevword': 'และ',
#    'word.prevwordisdigit': False,
#    'word.word': 'กระบวนการ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'ก็',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'กระบวนการ',
#    'word.prevwordisdigit': False,
#    'word.word': 'รัฐธรรมนูญ'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'คือ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'รัฐธรรมนูญ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ก็'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'เมื่อ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ก็',
#    'word.prevwordisdigit': False,
#    'word.word': 'คือ'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ก่อน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'คือ',
#    'word.prevwordisdigit': False,
#    'word.word': 'เมื่อ'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'FIXN',
#    'word.nextword': 'การ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'เมื่อ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ก่อน'},
#   {'postag': 'FIXN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ชุมนุม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ก่อน',
#    'word.prevwordisdigit': False,
#    'word.word': 'การ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ของ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'FIXN',
#    'word.previsspace': False,
#    'word.prevword': 'การ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ชุมนุม'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'บุคคล',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ชุมนุม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ของ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DIAC',
#    'word.nextword': 'ใด',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ของ',
#    'word.prevwordisdigit': False,
#    'word.word': 'บุคคล'},
#   {'postag': 'DIAC',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JCRG',
#    'word.nextword': 'ก็ตาม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'บุคคล',
#    'word.prevwordisdigit': False,
#    'word.word': 'ใด'},
#   {'postag': 'JCRG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'ก็',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DIAC',
#    'word.previsspace': False,
#    'word.prevword': 'ใด',
#    'word.prevwordisdigit': False,
#    'word.word': 'ก็ตาม'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVBM',
#    'word.nextword': 'จะ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JCRG',
#    'word.previsspace': False,
#    'word.prevword': 'ก็ตาม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ก็'},
#   {'postag': 'XVBM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'อ้าง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ก็',
#    'word.prevwordisdigit': False,
#    'word.word': 'จะ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ตาม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVBM',
#    'word.previsspace': False,
#    'word.prevword': 'จะ',
#    'word.prevwordisdigit': False,
#    'word.word': 'อ้าง'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'รัฐธรรมนูญ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'อ้าง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ตาม'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'มาตรา',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ตาม',
#    'word.prevwordisdigit': False,
#    'word.word': 'รัฐธรรมนูญ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCNM',
#    'word.nextword': '25',
#    'word.nextwordisdigit': True,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'รัฐธรรมนูญ',
#    'word.prevwordisdigit': False,
#    'word.word': 'มาตรา'},
#   {'postag': 'NCNM',
#    'word.isdigit()': True,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PNTR',
#    'word.nextword': 'อ้าง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'มาตรา',
#    'word.prevwordisdigit': False,
#    'word.word': '25'},
#   {'postag': 'PNTR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'ว่า',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCNM',
#    'word.previsspace': False,
#    'word.prevword': '25',
#    'word.prevwordisdigit': True,
#    'word.word': 'อ้าง'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'มี',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PNTR',
#    'word.previsspace': False,
#    'word.prevword': 'อ้าง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ว่า'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'สิทธิ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ว่า',
#    'word.prevwordisdigit': False,
#    'word.word': 'มี'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'เสรีภาพ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'มี',
#    'word.prevwordisdigit': False,
#    'word.word': 'สิทธิ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JCRG',
#    'word.nextword': 'และ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'สิทธิ',
#    'word.prevwordisdigit': False,
#    'word.word': 'เสรีภาพ'},
#   {'postag': 'JCRG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ศักดิ์ศรี',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'เสรีภาพ',
#    'word.prevwordisdigit': False,
#    'word.word': 'และ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ความเป็นมนุษย์',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JCRG',
#    'word.previsspace': False,
#    'word.prevword': 'และ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ศักดิ์ศรี'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ใน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ศักดิ์ศรี',
#    'word.prevwordisdigit': False,
#    'word.word': 'ความเป็นมนุษย์'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'FIXN',
#    'word.nextword': 'การ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ความเป็นมนุษย์',
#    'word.prevwordisdigit': False,
#    'word.word': 'ใน'},
#   {'postag': 'FIXN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ชุมนุม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ใน',
#    'word.prevwordisdigit': False,
#    'word.word': 'การ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ใน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'FIXN',
#    'word.previsspace': False,
#    'word.prevword': 'การ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ชุมนุม'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'วัน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ชุมนุม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ใน'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DDAC',
#    'word.nextword': 'นี้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ใน',
#    'word.prevwordisdigit': False,
#    'word.word': 'วัน'},
#   {'postag': 'DDAC',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'เมื่อ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'วัน',
#    'word.prevwordisdigit': False,
#    'word.word': 'นี้'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'FIXN',
#    'word.nextword': 'การ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DDAC',
#    'word.previsspace': False,
#    'word.prevword': 'นี้',
#    'word.prevwordisdigit': False,
#    'word.word': 'เมื่อ'},
#   {'postag': 'FIXN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ชุมนุม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'เมื่อ',
#    'word.prevwordisdigit': False,
#    'word.word': 'การ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVAE',
#    'word.nextword': 'ไป',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'FIXN',
#    'word.previsspace': False,
#    'word.prevword': 'การ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ชุมนุม'},
#   {'postag': 'XVAE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ถึง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ชุมนุม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ไป'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ระดับ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVAE',
#    'word.previsspace': False,
#    'word.prevword': 'ไป',
#    'word.prevwordisdigit': False,
#    'word.word': 'ถึง'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DCNM',
#    'word.nextword': 'หนึ่ง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ถึง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ระดับ'},
#   {'postag': 'DCNM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'ก็',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ระดับ',
#    'word.prevwordisdigit': False,
#    'word.word': 'หนึ่ง'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ไป',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DCNM',
#    'word.previsspace': False,
#    'word.prevword': 'หนึ่ง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ก็'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ละเมิด',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ก็',
#    'word.prevwordisdigit': False,
#    'word.word': 'ไป'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'สิทธิ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ไป',
#    'word.prevwordisdigit': False,
#    'word.word': 'ละเมิด'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ของ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ละเมิด',
#    'word.prevwordisdigit': False,
#    'word.word': 'สิทธิ'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'บุคคล',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'สิทธิ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ของ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DIAC',
#    'word.nextword': 'อื่น',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ของ',
#    'word.prevwordisdigit': False,
#    'word.word': 'บุคคล'},
#   {'postag': 'DIAC',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'ADVN',
#    'word.nextword': 'มากมาย',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'บุคคล',
#    'word.prevwordisdigit': False,
#    'word.word': 'อื่น'},
#   {'postag': 'ADVN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JCRG',
#    'word.nextword': 'และ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DIAC',
#    'word.previsspace': False,
#    'word.prevword': 'อื่น',
#    'word.prevwordisdigit': False,
#    'word.word': 'มากมาย'},
#   {'postag': 'JCRG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NEG',
#    'word.nextword': 'ไม่',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'ADVN',
#    'word.previsspace': False,
#    'word.prevword': 'มากมาย',
#    'word.prevwordisdigit': False,
#    'word.word': 'และ'},
#   {'postag': 'NEG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'เคารพ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JCRG',
#    'word.previsspace': False,
#    'word.prevword': 'และ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ไม่'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'กฎหมาย',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NEG',
#    'word.previsspace': False,
#    'word.prevword': 'ไม่',
#    'word.prevwordisdigit': False,
#    'word.word': 'เคารพ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DIAC',
#    'word.nextword': 'ต่างๆ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'เคารพ',
#    'word.prevwordisdigit': False,
#    'word.word': 'กฎหมาย'},
#   {'postag': 'DIAC',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'ADVN',
#    'word.nextword': 'มากมาย',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'กฎหมาย',
#    'word.prevwordisdigit': False,
#    'word.word': 'ต่างๆ'},
#   {'postag': 'ADVN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVBM',
#    'word.nextword': 'จึง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DIAC',
#    'word.previsspace': False,
#    'word.prevword': 'ต่างๆ',
#    'word.prevwordisdigit': False,
#    'word.word': 'มากมาย'},
#   {'postag': 'XVBM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ทำให้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'ADVN',
#    'word.previsspace': False,
#    'word.prevword': 'มากมาย',
#    'word.prevwordisdigit': False,
#    'word.word': 'จึง'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'FIXN',
#    'word.nextword': 'การ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVBM',
#    'word.previsspace': False,
#    'word.prevword': 'จึง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ทำให้'},
#   {'postag': 'FIXN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ชุมนุม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ทำให้',
#    'word.prevwordisdigit': False,
#    'word.word': 'การ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ใน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'FIXN',
#    'word.previsspace': False,
#    'word.prevword': 'การ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ชุมนุม'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ขณะนี้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ชุมนุม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ใน'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NEG',
#    'word.nextword': 'มิ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ใน',
#    'word.prevwordisdigit': False,
#    'word.word': 'ขณะนี้'},
#   {'postag': 'NEG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVAE',
#    'word.nextword': 'ได้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ขณะนี้',
#    'word.prevwordisdigit': False,
#    'word.word': 'มิ'},
#   {'postag': 'XVAE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'เป็นไปตาม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NEG',
#    'word.previsspace': False,
#    'word.prevword': 'มิ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ได้'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'กระบวน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVAE',
#    'word.previsspace': False,
#    'word.prevword': 'ได้',
#    'word.prevwordisdigit': False,
#    'word.word': 'เป็นไปตาม'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VATT',
#    'word.nextword': 'การปกครอง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'เป็นไปตาม',
#    'word.prevwordisdigit': False,
#    'word.word': 'กระบวน'},
#   {'postag': 'VATT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ตาม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'กระบวน',
#    'word.prevwordisdigit': False,
#    'word.word': 'การปกครอง'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ระบอบ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VATT',
#    'word.previsspace': False,
#    'word.prevword': 'การปกครอง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ตาม'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ประชาธิปไตย',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ตาม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ระบอบ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PREL',
#    'word.nextword': 'อัน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ระบอบ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ประชาธิปไตย'},
#   {'postag': 'PREL',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'มี',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ประชาธิปไตย',
#    'word.prevwordisdigit': False,
#    'word.word': 'อัน'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'พระมหากษัตริย์',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PREL',
#    'word.previsspace': False,
#    'word.prevword': 'อัน',
#    'word.prevwordisdigit': False,
#    'word.word': 'มี'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ทรง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'มี',
#    'word.prevwordisdigit': False,
#    'word.word': 'พระมหากษัตริย์'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'เป็น',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'พระมหากษัตริย์',
#    'word.prevwordisdigit': False,
#    'word.word': 'ทรง'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'พระ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ทรง',
#    'word.prevwordisdigit': False,
#    'word.word': 'เป็น'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ประมุข',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'เป็น',
#    'word.prevwordisdigit': False,
#    'word.word': 'พระ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'ขณะที่',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'พระ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ประมุข'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'FIXN',
#    'word.nextword': 'การ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ประมุข',
#    'word.prevwordisdigit': False,
#    'word.word': 'ขณะที่'},
#   {'postag': 'FIXN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ชุมนุม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ขณะที่',
#    'word.prevwordisdigit': False,
#    'word.word': 'การ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ใน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'FIXN',
#    'word.previsspace': False,
#    'word.prevword': 'การ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ชุมนุม'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'วัน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ชุมนุม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ใน'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DDAC',
#    'word.nextword': 'นั้น',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ใน',
#    'word.prevwordisdigit': False,
#    'word.word': 'วัน'},
#   {'postag': 'DDAC',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'มี',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'วัน',
#    'word.prevwordisdigit': False,
#    'word.word': 'นั้น'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'แกนนำ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DDAC',
#    'word.previsspace': False,
#    'word.prevword': 'นั้น',
#    'word.prevwordisdigit': False,
#    'word.word': 'มี'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVAE',
#    'word.nextword': 'ขึ้น',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'มี',
#    'word.prevwordisdigit': False,
#    'word.word': 'แกนนำ'},
#   {'postag': 'XVAE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ปราศรัย',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'แกนนำ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ขึ้น'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DIBQ',
#    'word.nextword': 'ประมาณ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVAE',
#    'word.previsspace': False,
#    'word.prevword': 'ขึ้น',
#    'word.prevwordisdigit': False,
#    'word.word': 'ปราศรัย'},
#   {'postag': 'DIBQ',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DCNM',
#    'word.nextword': '10',
#    'word.nextwordisdigit': True,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ปราศรัย',
#    'word.prevwordisdigit': False,
#    'word.word': 'ประมาณ'},
#   {'postag': 'DCNM',
#    'word.isdigit()': True,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'CNIT',
#    'word.nextword': 'คน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DIBQ',
#    'word.previsspace': False,
#    'word.prevword': 'ประมาณ',
#    'word.prevwordisdigit': False,
#    'word.word': '10'},
#   {'postag': 'CNIT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JCRG',
#    'word.nextword': 'และ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DCNM',
#    'word.previsspace': False,
#    'word.prevword': '10',
#    'word.prevwordisdigit': True,
#    'word.word': 'คน'},
#   {'postag': 'JCRG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ทำให้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'CNIT',
#    'word.previsspace': False,
#    'word.prevword': 'คน',
#    'word.prevwordisdigit': False,
#    'word.word': 'และ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DDAC',
#    'word.nextword': 'เมื่อคืนนี้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JCRG',
#    'word.previsspace': False,
#    'word.prevword': 'และ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ทำให้'},
#   {'postag': 'DDAC',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PUNC',
#    'word.nextword': '(',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ทำให้',
#    'word.prevwordisdigit': False,
#    'word.word': 'เมื่อคืนนี้'},
#   {'postag': 'PUNC',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCNM',
#    'word.nextword': '12',
#    'word.nextwordisdigit': True,
#    'word.prepostag': 'DDAC',
#    'word.previsspace': False,
#    'word.prevword': 'เมื่อคืนนี้',
#    'word.prevwordisdigit': False,
#    'word.word': '('},
#   {'postag': 'NCNM',
#    'word.isdigit()': True,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DCNM',
#    'word.nextword': 'ส.ค.',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PUNC',
#    'word.previsspace': False,
#    'word.prevword': '(',
#    'word.prevwordisdigit': False,
#    'word.word': '12'},
#   {'postag': 'DCNM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCNM',
#    'word.nextword': '63',
#    'word.nextwordisdigit': True,
#    'word.prepostag': 'NCNM',
#    'word.previsspace': False,
#    'word.prevword': '12',
#    'word.prevwordisdigit': True,
#    'word.word': 'ส.ค.'},
#   {'postag': 'NCNM',
#    'word.isdigit()': True,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PUNC',
#    'word.nextword': ')',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DCNM',
#    'word.previsspace': False,
#    'word.prevword': 'ส.ค.',
#    'word.prevwordisdigit': False,
#    'word.word': '63'},
#   {'postag': 'PUNC',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ทาง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCNM',
#    'word.previsspace': False,
#    'word.prevword': '63',
#    'word.prevwordisdigit': True,
#    'word.word': ')'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'แกนนำ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PUNC',
#    'word.previsspace': False,
#    'word.prevword': ')',
#    'word.prevwordisdigit': False,
#    'word.word': 'ทาง'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'อ้างว่า',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ทาง',
#    'word.prevwordisdigit': False,
#    'word.word': 'แกนนำ'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'มี',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'แกนนำ',
#    'word.prevwordisdigit': False,
#    'word.word': 'อ้างว่า'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ตำรวจ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'อ้างว่า',
#    'word.prevwordisdigit': False,
#    'word.word': 'มี'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVAE',
#    'word.nextword': 'ไป',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'มี',
#    'word.prevwordisdigit': False,
#    'word.word': 'ตำรวจ'},
#   {'postag': 'XVAE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'สังเกตการณ์',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ตำรวจ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ไป'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'บริเวณ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVAE',
#    'word.previsspace': False,
#    'word.prevword': 'ไป',
#    'word.prevwordisdigit': False,
#    'word.word': 'สังเกตการณ์'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'รอบ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'สังเกตการณ์',
#    'word.prevwordisdigit': False,
#    'word.word': 'บริเวณ'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ที่พัก',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'บริเวณ',
#    'word.prevwordisdigit': False,
#    'word.word': 'รอบ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'เพื่อ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'รอบ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ที่พัก'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'รอ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ที่พัก',
#    'word.prevwordisdigit': False,
#    'word.word': 'เพื่อ'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ควบคุม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'เพื่อ',
#    'word.prevwordisdigit': False,
#    'word.word': 'รอ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'CNIT',
#    'word.nextword': 'ตัว',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'รอ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ควบคุม'},
#   {'postag': 'CNIT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JCRG',
#    'word.nextword': 'แต่',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ควบคุม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ตัว'},
#   {'postag': 'JCRG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'จนถึง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'CNIT',
#    'word.previsspace': False,
#    'word.prevword': 'ตัว',
#    'word.prevwordisdigit': False,
#    'word.word': 'แต่'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'ADVS',
#    'word.nextword': 'ขณะนี้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JCRG',
#    'word.previsspace': False,
#    'word.prevword': 'แต่',
#    'word.prevwordisdigit': False,
#    'word.word': 'จนถึง'},
#   {'postag': 'ADVS',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVBM',
#    'word.nextword': 'ยัง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'จนถึง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ขณะนี้'},
#   {'postag': 'XVBM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NEG',
#    'word.nextword': 'ไม่',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'ADVS',
#    'word.previsspace': False,
#    'word.prevword': 'ขณะนี้',
#    'word.prevwordisdigit': False,
#    'word.word': 'ยัง'},
#   {'postag': 'NEG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'มี',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVBM',
#    'word.previsspace': False,
#    'word.prevword': 'ยัง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ไม่'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'FIXN',
#    'word.nextword': 'การ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NEG',
#    'word.previsspace': False,
#    'word.prevword': 'ไม่',
#    'word.prevwordisdigit': False,
#    'word.word': 'มี'},
#   {'postag': 'FIXN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ดำเนินการ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'มี',
#    'word.prevwordisdigit': False,
#    'word.word': 'การ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DIAC',
#    'word.nextword': 'ใดๆ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'FIXN',
#    'word.previsspace': False,
#    'word.prevword': 'การ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ดำเนินการ'},
#   {'EOS': True,
#    'postag': 'DIAC',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ดำเนินการ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ใดๆ'}],
#  [{'BOS': True,
#    'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'มี',
#    'word.nextwordisdigit': False,
#    'word.word': 'ขณะที่'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'รายงาน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ขณะที่',
#    'word.prevwordisdigit': False,
#    'word.word': 'มี'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'ว่า',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'มี',
#    'word.prevwordisdigit': False,
#    'word.word': 'รายงาน'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'FIXN',
#    'word.nextword': 'การ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'รายงาน',
#    'word.prevwordisdigit': False,
#    'word.word': 'ว่า'},
#   {'postag': 'FIXN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ดักรอ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ว่า',
#    'word.prevwordisdigit': False,
#    'word.word': 'การ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
# ...
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DIBQ',
#    'word.nextword': 'หลาย',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVAE',
#    'word.previsspace': False,
#    'word.prevword': 'มา',
#    'word.prevwordisdigit': False,
#    'word.word': 'นาน'},
#   {'postag': 'DIBQ',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'CMTR',
#    'word.nextword': 'ปี',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'ADVN',
#    'word.previsspace': False,
#    'word.prevword': 'นาน',
#    'word.prevwordisdigit': False,
#    'word.word': 'หลาย'},
#   {'postag': 'CMTR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'แล้ว',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DIBQ',
#    'word.previsspace': False,
#    'word.prevword': 'หลาย',
#    'word.prevwordisdigit': False,
#    'word.word': 'ปี'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DDBQ',
#    'word.nextword': 'อีก',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'CMTR',
#    'word.previsspace': False,
#    'word.prevword': 'ปี',
#    'word.prevwordisdigit': False,
#    'word.word': 'แล้ว'},
#   {'postag': 'DDBQ',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'DDBQ',
#    'word.nextword': 'ทั้ง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'แล้ว',
#    'word.prevwordisdigit': False,
#    'word.word': 'อีก'},
#   {'postag': 'DDBQ',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NEG',
#    'word.nextword': 'ไม่',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DDBQ',
#    'word.previsspace': False,
#    'word.prevword': 'อีก',
#    'word.prevwordisdigit': False,
#    'word.word': 'ทั้ง'},
#   {'postag': 'NEG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVMM',
#    'word.nextword': 'เคย',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'DDBQ',
#    'word.previsspace': False,
#    'word.prevword': 'ทั้ง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ไม่'},
#   {'postag': 'XVMM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'คิด',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NEG',
#    'word.previsspace': False,
#    'word.prevword': 'ไม่',
#    'word.prevwordisdigit': False,
#    'word.word': 'เคย'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PREL',
#    'word.nextword': 'ที่',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVMM',
#    'word.previsspace': False,
#    'word.prevword': 'เคย',
#    'word.prevwordisdigit': False,
#    'word.word': 'คิด'},
#   {'postag': 'PREL',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVBM',
#    'word.nextword': 'จะ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'คิด',
#    'word.prevwordisdigit': False,
#    'word.word': 'ที่'},
#   {'postag': 'XVBM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ทำ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PREL',
#    'word.previsspace': False,
#    'word.prevword': 'ที่',
#    'word.prevwordisdigit': False,
#    'word.word': 'จะ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'RPRE',
#    'word.nextword': 'ด้วย',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVBM',
#    'word.previsspace': False,
#    'word.prevword': 'จะ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ทำ'},
#   {'postag': 'RPRE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'เพราะ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ทำ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ด้วย'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PDMN',
#    'word.nextword': 'ตนเอง',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'RPRE',
#    'word.previsspace': False,
#    'word.prevword': 'ด้วย',
#    'word.prevwordisdigit': False,
#    'word.word': 'เพราะ'},
#   {'postag': 'PDMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'ก็',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'เพราะ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ตนเอง'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'เรียก',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PDMN',
#    'word.previsspace': False,
#    'word.prevword': 'ตนเอง',
#    'word.prevwordisdigit': False,
#    'word.word': 'ก็'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'ADVI',
#    'word.nextword': 'เด็ก',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ก็',
#    'word.prevwordisdigit': False,
#    'word.word': 'เรียก'},
#   {'postag': 'ADVI',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'ว่า',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'เรียก',
#    'word.prevwordisdigit': False,
#    'word.word': 'เด็ก'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'หลาน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'ADVI',
#    'word.previsspace': False,
#    'word.prevword': 'เด็ก',
#    'word.prevwordisdigit': False,
#    'word.word': 'ว่า'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'อย่างไรก็ตาม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'ว่า',
#    'word.prevwordisdigit': False,
#    'word.word': 'หลาน'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'พร้อม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'หลาน',
#    'word.prevwordisdigit': False,
#    'word.word': 'อย่างไรก็ตาม'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PREL',
#    'word.nextword': 'ที่',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'อย่างไรก็ตาม',
#    'word.prevwordisdigit': False,
#    'word.word': 'พร้อม'},
#   {'postag': 'PREL',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVBM',
#    'word.nextword': 'จะ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'พร้อม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ที่'},
#   {'postag': 'XVBM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ยืนยัน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PREL',
#    'word.previsspace': False,
#    'word.prevword': 'ที่',
#    'word.prevwordisdigit': False,
#    'word.word': 'จะ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ความบริสุทธิ์',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVBM',
#    'word.previsspace': False,
#    'word.prevword': 'จะ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ยืนยัน'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JCRG',
#    'word.nextword': 'หรือ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ยืนยัน',
#    'word.prevwordisdigit': False,
#    'word.word': 'ความบริสุทธิ์'},
#   {'postag': 'JCRG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVBM',
#    'word.nextword': 'จะ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ความบริสุทธิ์',
#    'word.prevwordisdigit': False,
#    'word.word': 'หรือ'},
#   {'postag': 'XVBM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'พา',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JCRG',
#    'word.previsspace': False,
#    'word.prevword': 'หรือ',
#    'word.prevwordisdigit': False,
#    'word.word': 'จะ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVAE',
#    'word.nextword': 'ไป',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVBM',
#    'word.previsspace': False,
#    'word.prevword': 'จะ',
#    'word.prevwordisdigit': False,
#    'word.word': 'พา'},
#   {'postag': 'XVAE',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'สาบาน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'พา',
#    'word.prevwordisdigit': False,
#    'word.word': 'ไป'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PNTR',
#    'word.nextword': 'ที่ไหน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVAE',
#    'word.previsspace': False,
#    'word.prevword': 'ไป',
#    'word.prevwordisdigit': False,
#    'word.word': 'สาบาน'},
#   {'postag': 'PNTR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'EAFF',
#    'word.nextword': 'ก็ได้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'สาบาน',
#    'word.prevwordisdigit': False,
#    'word.word': 'ที่ไหน'},
#   {'postag': 'EAFF',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VSTA',
#    'word.nextword': 'พร้อม',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PNTR',
#    'word.previsspace': False,
#    'word.prevword': 'ที่ไหน',
#    'word.prevwordisdigit': False,
#    'word.word': 'ก็ได้'},
#   {'postag': 'VSTA',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PREL',
#    'word.nextword': 'ที่',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'EAFF',
#    'word.previsspace': False,
#    'word.prevword': 'ก็ได้',
#    'word.prevwordisdigit': False,
#    'word.word': 'พร้อม'},
#   {'postag': 'PREL',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVBM',
#    'word.nextword': 'จะ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VSTA',
#    'word.previsspace': False,
#    'word.prevword': 'พร้อม',
#    'word.prevwordisdigit': False,
#    'word.word': 'ที่'},
#   {'postag': 'XVBM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ตรวจ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PREL',
#    'word.previsspace': False,
#    'word.prevword': 'ที่',
#    'word.prevwordisdigit': False,
#    'word.word': 'จะ'},
#   {'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'ADVN',
#    'word.nextword': 'พิสูจน์',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'XVBM',
#    'word.previsspace': False,
#    'word.prevword': 'จะ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ตรวจ'},
#   {'postag': 'ADVN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ร่างกาย',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'VACT',
#    'word.previsspace': False,
#    'word.prevword': 'ตรวจ',
#    'word.prevwordisdigit': False,
#    'word.word': 'พิสูจน์'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JCRG',
#    'word.nextword': 'และ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'ADVN',
#    'word.previsspace': False,
#    'word.prevword': 'พิสูจน์',
#    'word.prevwordisdigit': False,
#    'word.word': 'ร่างกาย'},
#   {'postag': 'JCRG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'ต่อสู้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ร่างกาย',
#    'word.prevwordisdigit': False,
#    'word.word': 'และ'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NCMN',
#    'word.nextword': 'คดี',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JCRG',
#    'word.previsspace': False,
#    'word.prevword': 'และ',
#    'word.prevwordisdigit': False,
#    'word.word': 'ต่อสู้'},
#   {'postag': 'NCMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'JSBR',
#    'word.nextword': 'เนื่องจาก',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'ต่อสู้',
#    'word.prevwordisdigit': False,
#    'word.word': 'คดี'},
#   {'postag': 'JSBR',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'PDMN',
#    'word.nextword': 'ตน',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NCMN',
#    'word.previsspace': False,
#    'word.prevword': 'คดี',
#    'word.prevwordisdigit': False,
#    'word.word': 'เนื่องจาก'},
#   {'postag': 'PDMN',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'NEG',
#    'word.nextword': 'ไม่',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'JSBR',
#    'word.previsspace': False,
#    'word.prevword': 'เนื่องจาก',
#    'word.prevwordisdigit': False,
#    'word.word': 'ตน'},
#   {'postag': 'NEG',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'XVAM',
#    'word.nextword': 'ได้',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'PDMN',
#    'word.previsspace': False,
#    'word.prevword': 'ตน',
#    'word.prevwordisdigit': False,
#    'word.word': 'ไม่'},
#   {'postag': 'XVAM',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.nextisspace': False,
#    'word.nextpostag': 'VACT',
#    'word.nextword': 'ทำ',
#    'word.nextwordisdigit': False,
#    'word.prepostag': 'NEG',
#    'word.previsspace': False,
#    'word.prevword': 'ไม่',
#    'word.prevwordisdigit': False,
#    'word.word': 'ได้'},
#   {'EOS': True,
#    'postag': 'VACT',
#    'word.isdigit()': False,
#    'word.isspace': False,
#    'word.prepostag': 'XVAM',
#    'word.previsspace': False,
#    'word.prevword': 'ได้',
#    'word.prevwordisdigit': False,
#    'word.word': 'ทำ'}]]

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True,
    model_filename=file_name+"-pos.model1"
)
crf.fit(X_data, y_data)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CRF(algorithm='lbfgs', all_possible_states=None, all_possible_transitions=True,
#     averaging=None, c=None, c1=0.1, c2=0.1, calibration_candidates=None,
#     calibration_eta=None, calibration_max_trials=None, calibration_rate=None,
#     calibration_samples=None, delta=None, epsilon=None, error_sensitive=None,
#     gamma=None, keep_tempfiles=None, linesearch=None, max_iterations=100,
#     max_linesearch=None, min_freq=None, model_filename=None, num_memories=None,
#     pa_type=None, period=None, trainer_cls=None, variance=None, verbose=False)

# %%
X, X_test, y, y_test = train_test_split(X_data, y_data, test_size=0.1) # แบ่ง 0.1 หรือ 10%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    max_iterations=100,
    all_possible_transitions=True,
    model_filename=file_name+"-pos.model1" # ตั้งชื่อโมเดล
)

params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}
labels = list(crf.classes_)
labels.remove('O')
f1_scorer = make_scorer(metrics.flat_f1_score,
                        average='weighted', labels=labels)
rs = RandomizedSearchCV(crf, params_space,
                        cv=3,
                        verbose=1,
                        n_jobs=-1,
                        n_iter=50,
                        scoring=f1_scorer)
rs.fit(X_data, y_data)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   43.0s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  2.3min finished
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=CRF(algorithm='lbfgs', all_possible_states=None,
#                                  all_possible_transitions=True, averaging=None,
#                                  c=None, c1=None, c2=None,
#                                  calibration_candidates=None,
#                                  calibration_eta=None,
#                                  calibration_max_trials=None,
#                                  calibration_rate=None,
#                                  calibration_samples=None, delta=None,
#                                  epsilon=None, error_sensitive=None, gamma=None,
#                                  keep_...
#                    scoring=make_scorer(flat_f1_score, average=weighted, labels=['Prepositions', 'noun', 'SSConjunctions', 'intransitiveverb', 'wordbeforeverb', 'transitiveverb', 'Negator', 'wordafterverb', 'NounConjunctions', 'Timeexpressionword', 'Pronouns', 'Adverbs', 'Numeralword', 'PhrasalVerbs', 'Nounphrase', 'wordbeforenumeral', 'Qualitativenoun', 'abbreviation', 'wordbeforenoun', 'Sequenceword', 'Adjectives', 'wordafternumeral']),
#                    verbose=1)

# %%
y_pred = crf.predict(X_test)
e=metrics.flat_f1_score(y_test, y_pred,
                      average='weighted', labels=labels)
print(e) # โชว์ประสิทธิภาพ
# Out:
# 0.9818894944973119
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1515: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   average, "true nor predicted", 'F-score is', len(true_sum)

# %%
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#                     precision    recall  f1-score   support
#
#     SSConjunctions      1.000     0.857     0.923        14
#       abbreviation      1.000     1.000     1.000         6
#         Adjectives      0.000     0.000     0.000         0
#            Adverbs      1.000     0.909     0.952        11
#            Negator      1.000     1.000     1.000         5
#       Sequenceword      0.000     0.000     0.000         0
#       PhrasalVerbs      1.000     1.000     1.000        18
# Timeexpressionword      1.000     1.000     1.000        18
#   intransitiveverb      1.000     0.800     0.889         5
#   wordafternumeral      0.000     0.000     0.000         0
#      wordafterverb      1.000     1.000     1.000         7
#     wordbeforenoun      1.000     1.000     1.000         5
#  wordbeforenumeral      1.000     1.000     1.000         1
#     wordbeforeverb      0.900     1.000     0.947        18
#               noun      0.993     0.986     0.990       146
#   NounConjunctions      0.917     1.000     0.957        11
#         Nounphrase      1.000     1.000     1.000         7
#     transitiveverb      1.000     1.000     1.000        45
#       Prepositions      0.850     1.000     0.919        17
#           Pronouns      1.000     1.000     1.000         7
#    Qualitativenoun      1.000     1.000     1.000         3
#        Numeralword      1.000     1.000     1.000        13
#
#          micro avg      0.980     0.983     0.982       357
#          macro avg      0.848     0.843     0.844       357
#       weighted avg      0.982     0.983     0.982       357
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# best params: {'c1': 0.2238089165326937, 'c2': 0.0011345082014079277}
# best CV score: 0.6247865328128516
# model size: 0.19M

# %%
_x = [s['c1'] for s in rs.cv_results_['params']]
_y = [s['c2'] for s in rs.cv_results_['params']]
_c = [s for s in rs.cv_results_['mean_test_score']]

# %%
fig = plt.figure()
fig.set_size_inches(12, 12)
ax = plt.gca()
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlabel('C1')
ax.set_ylabel('C2')
ax.set_title("Randomized Hyperparameter Search CV Results (min={:0.3}, max={:0.3})".
format(
min(_c), max(_c)
))
ax.scatter(_x, _y, c=_c, s=60, alpha=0.9, edgecolors=[0,0,0])
print("Dark blue => {:0.4}, dark red => {:0.4}".format(min(_c), max(_c)))
# Out:
# Dark blue => 0.5797, dark red => 0.6248

# %%
from collections import Counter
def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))
print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))
print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# Nounphrase -> Nounphrase 4.143566
# PhrasalVerbs -> PhrasalVerbs 3.715780
# Numeralword -> Qualitativenoun 3.358721
# Timeexpressionword -> Timeexpressionword 2.899868
# Prepositions -> Prepositions 2.589105
# noun   -> noun    2.505588
# wordbeforeverb -> intransitiveverb 2.486008
# Pronouns -> Adjectives 2.411666
# wordafterverb -> wordafterverb 2.385765
# wordbeforenoun -> noun    2.382828
# O      -> O       2.316242
# Adverbs -> O       2.256832
# Adverbs -> Adverbs 2.225811
# NounConjunctions -> NounConjunctions 2.223469
# abbreviation -> noun    2.211074
# wordbeforenumeral -> Numeralword 2.109505
# wordbeforeverb -> transitiveverb 2.092131
# transitiveverb -> noun    2.023808
# Numeralword -> abbreviation 1.878888
# intransitiveverb -> wordafterverb 1.836033
#
# Top unlikely transitions:
# Negator -> noun    -1.004719
# wordbeforeverb -> Adverbs -1.064025
# Nounphrase -> wordbeforeverb -1.069797
# Nounphrase -> O       -1.083660
# transitiveverb -> Timeexpressionword -1.123340
# Nounphrase -> wordafterverb -1.142691
# PhrasalVerbs -> transitiveverb -1.149986
# Prepositions -> wordbeforeverb -1.190921
# wordafterverb -> NounConjunctions -1.243568
# wordbeforeverb -> Nounphrase -1.274769
# PhrasalVerbs -> wordafterverb -1.313521
# O      -> Prepositions -1.325617
# Timeexpressionword -> NounConjunctions -1.350422
# wordafterverb -> PhrasalVerbs -1.406737
# Adverbs -> Negator -1.430975
# noun   -> Nounphrase -1.466506
# intransitiveverb -> PhrasalVerbs -1.522452
# O      -> NounConjunctions -1.598601
# transitiveverb -> PhrasalVerbs -1.640256
# PhrasalVerbs -> wordbeforeverb -1.731736

# %%
d = []
while True:
    t=input("Text : ")    
    print(get_ner(t))
# Out:
# Text : เรียน ผู้บังคับบัญชา    ตาม สั่งการของ ผบช.ปส. มอบหมาย กก.ปพ.บช.ปส. และ  บก.ขส.ตรวจสอบข้อมูล บุคคลที่ติดต่อขอเยี่ยมผู้ต้องหา และเก็บเป็นข้อมูลในการสืบสวนขยายผล ต่อไปนั้น     วันนี้(29 พ.ค.63) ร.ต.อ.เสนีย์ มั่นใหญ่ ร้อยเวร กก.ปพ.ฯ ได้ดำเนินการตรวจสอบข้อมูลบุคคลผู้เข้ามาเยี่ยมผู้ต้องหา ห้วงเวลา 09.00-10.00 น. สรุปผลการตรวจสอบได้ ดังนี้ 1. ในช่วงเวลาดังกล่าว มีผู้ต้องหาอยู่ในความควบคุม เป็นชาย 11 ราย หญิง 1 ราย 2. ในช่วงเวลาดังกล่าว พบว่ามีการขอเข้าเยี่ยมผู้ต้องหา 5 ราย แจ้ง บก.ขส. ตรวจสอบทั้งหมดแล้ว ไม่มีประวัติหรือหมายจับ แต่อย่างใด 3. ทั้งนี้ได้ดำเนินการแจ้งให้ บก.ขส.ทราบทางไลน์ไว้เบื้องต้นแล้ว และจะได้ดำเนินการจัดทำบันทึกไว้เป็นหลักฐานมอบให้กับ บก.ขส.บช.ปส.ต่อไป    จึงเรียนมาเพื่อโปรดทราบ
# (True, ['transitiveverb', 'noun', 'Prepositions', 'noun', 'NounConjunctions', 'noun', 'noun', 'wordbeforeverb', 'transitiveverb', 'noun', 'noun', 'noun', 'noun', 'NounConjunctions', 'noun', 'noun', 'transitiveverb', 'Nounphrase', 'Nounphrase', 'SSConjunctions', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'noun', 'NounConjunctions', 'transitiveverb', 'transitiveverb', 'noun', 'Prepositions', 'noun', 'noun', 'Adverbs', 'O', 'O', 'Numeralword', 'abbreviation', 'Numeralword', 'abbreviation', 'noun', 'noun', 'noun', 'noun', 'noun', 'noun', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'Nounphrase', 'Nounphrase', 'Nounphrase', 'PhrasalVerbs', 'PhrasalVerbs', 'noun', 'noun', 'noun', 'O', 'Numeralword', 'abbreviation', 'transitiveverb', 'Nounphrase', 'Nounphrase', 'Nounphrase', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'Prepositions', 'noun', 'Pronouns', 'transitiveverb', 'noun', 'transitiveverb', 'Prepositions', 'noun', 'noun', 'transitiveverb', 'noun', 'Numeralword', 'Qualitativenoun', 'noun', 'Numeralword', 'Qualitativenoun', 'transitiveverb', 'Prepositions', 'noun', 'wordbeforeverb', 'transitiveverb', 'SSConjunctions', 'transitiveverb', 'noun', 'noun', 'wordbeforeverb', 'transitiveverb', 'noun', 'Numeralword', 'Qualitativenoun', 'noun', 'noun', 'noun', 'noun', 'intransitiveverb', 'intransitiveverb', 'wordafterverb', 'Negator', 'Adverbs', 'O', 'noun', 'Adverbs', 'O', 'O', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'noun', 'O', 'transitiveverb', 'noun', 'noun', 'wordafterverb', 'wordafterverb', 'wordafterverb', 'O', 'wordbeforeverb', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'PhrasalVerbs', 'NounConjunctions', 'noun', 'O', 'noun', 'noun', 'Adverbs', 'wordbeforeverb', 'transitiveverb', 'transitiveverb', 'Prepositions', 'noun'])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-171-c0c60efa8fba> in <module>()
#       1 d = []
#       2 while True:
# ----> 3     t=input("Text : ")
#       4     print(get_ner(t))
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
d
# Out:
# [[('เรียน', 'transitiveverb'),
#   ('ผู้บังคับบัญชา', 'noun'),
#   ('ตาม', 'Prepositions'),
#   ('สั่งการ', 'noun'),
#   ('ของ', 'NounConjunctions'),
#   ('ผบ', 'noun'),
#   ('ช.', 'noun'),
#   ('ปส.', 'wordbeforeverb'),
#   ('มอบหมาย', 'transitiveverb'),
#   ('กก.', 'noun'),
#   ('ปพ.', 'noun'),
#   ('บช.', 'noun'),
#   ('ปส.', 'noun'),
#   ('และ', 'NounConjunctions'),
#   ('บก', 'noun'),
#   ('.ขส.', 'noun'),
#   ('ตรวจสอบ', 'transitiveverb'),
#   ('ข้อมูล', 'Nounphrase'),
#   ('บุคคล', 'Nounphrase'),
#   ('ที่', 'SSConjunctions'),
#   ('ติดต่อ', 'PhrasalVerbs'),
#   ('ขอ', 'PhrasalVerbs'),
#   ('เยี่ยม', 'PhrasalVerbs'),
#   ('ผู้ต้องหา', 'noun'),
#   ('และ', 'NounConjunctions'),
#   ('เก็บ', 'transitiveverb'),
#   ('เป็น', 'transitiveverb'),
#   ('ข้อมูล', 'noun'),
#   ('ใน', 'Prepositions'),
#   ('การสืบสวน', 'noun'),
#   ('ขยายผล', 'noun'),
#   ('ต่อไป', 'Adverbs'),
#   ('นั้น', 'O'),
#   ('วันนี้', 'O'),
#   ('29', 'Numeralword'),
#   ('พ.ค.', 'abbreviation'),
#   ('63', 'Numeralword'),
#   ('ร.ต.อ.', 'abbreviation'),
#   ('เสนีย์', 'noun'),
#   ('มั่น', 'noun'),
#   ('ใหญ่', 'noun'),
#   ('ร้อยเวร', 'noun'),
#   ('กก.', 'noun'),
#   ('ปพ.ฯ', 'noun'),
#   ('ได้', 'PhrasalVerbs'),
#   ('ดำเนินการ', 'PhrasalVerbs'),
#   ('ตรวจสอบ', 'PhrasalVerbs'),
#   ('ข้อมูล', 'Nounphrase'),
#   ('บุคคล', 'Nounphrase'),
#   ('ผู้', 'Nounphrase'),
#   ('เข้ามา', 'PhrasalVerbs'),
#   ('เยี่ยม', 'PhrasalVerbs'),
#   ('ผู้ต้องหา', 'noun'),
#   ('ห้วงเวลา', 'noun'),
#   ('09.00', 'noun'),
#   ('-', 'O'),
#   ('10.00', 'Numeralword'),
#   ('น.', 'abbreviation'),
#   ('สรุป', 'transitiveverb'),
#   ('ผล', 'Nounphrase'),
#   ('การ', 'Nounphrase'),
#   ('ตรวจสอบ', 'Nounphrase'),
#   ('ได้', 'PhrasalVerbs'),
#   ('ดังนี้', 'PhrasalVerbs'),
#   ('1.', 'PhrasalVerbs'),
#   ('ใน', 'Prepositions'),
#   ('ช่วงเวลา', 'noun'),
#   ('ดังกล่าว', 'Pronouns'),
#   ('มี', 'transitiveverb'),
#   ('ผู้ต้องหา', 'noun'),
#   ('อยู่', 'transitiveverb'),
#   ('ใน', 'Prepositions'),
#   ('ความ', 'noun'),
#   ('ควบคุม', 'noun'),
#   ('เป็น', 'transitiveverb'),
#   ('ชาย', 'noun'),
#   ('11', 'Numeralword'),
#   ('ราย', 'Qualitativenoun'),
#   ('หญิง', 'noun'),
#   ('1', 'Numeralword'),
#   ('ราย', 'Qualitativenoun'),
#   ('2.', 'transitiveverb'),
#   ('ใน', 'Prepositions'),
#   ('ช่วงเวลา', 'noun'),
#   ('ดังกล่าว', 'wordbeforeverb'),
#   ('พบ', 'transitiveverb'),
#   ('ว่า', 'SSConjunctions'),
#   ('มี', 'transitiveverb'),
#   ('การ', 'noun'),
#   ('ขอ', 'noun'),
#   ('เข้า', 'wordbeforeverb'),
#   ('เยี่ยม', 'transitiveverb'),
#   ('ผู้ต้องหา', 'noun'),
#   ('5', 'Numeralword'),
#   ('ราย', 'Qualitativenoun'),
#   ('แจ้', 'noun'),
#   ('งบ', 'noun'),
#   ('ก.', 'noun'),
#   ('ขส.', 'noun'),
#   ('ตรวจสอบ', 'intransitiveverb'),
#   ('ทั้งหมด', 'intransitiveverb'),
#   ('แล้ว', 'wordafterverb'),
#   ('ไม่', 'Negator'),
#   ('มีประวัติ', 'Adverbs'),
#   ('หรือ', 'O'),
#   ('หมายจับ', 'noun'),
#   ('แต่อย่างใด', 'Adverbs'),
#   ('3.', 'O'),
#   ('ทั้งนี้', 'O'),
#   ('ได้', 'PhrasalVerbs'),
#   ('ดำเนินการ', 'PhrasalVerbs'),
#   ('แจ้ง', 'PhrasalVerbs'),
#   ('ให้', 'PhrasalVerbs'),
#   ('บก', 'noun'),
#   ('.ขส.', 'O'),
#   ('ทราบ', 'transitiveverb'),
#   ('ทาง', 'noun'),
#   ('ไลน์', 'noun'),
#   ('ไว้', 'wordafterverb'),
#   ('เบื้องต้น', 'wordafterverb'),
#   ('แล้ว', 'wordafterverb'),
#   ('และ', 'O'),
#   ('จะ', 'wordbeforeverb'),
#   ('ได้', 'PhrasalVerbs'),
#   ('ดำเนินการ', 'PhrasalVerbs'),
#   ('จัดทำ', 'PhrasalVerbs'),
#   ('บันทึก', 'PhrasalVerbs'),
#   ('ไว้', 'PhrasalVerbs'),
#   ('เป็น', 'PhrasalVerbs'),
#   ('หลักฐาน', 'PhrasalVerbs'),
#   ('มอบให้', 'PhrasalVerbs'),
#   ('กับ', 'NounConjunctions'),
#   ('บก', 'noun'),
#   ('.ขส.', 'O'),
#   ('บช.', 'noun'),
#   ('ปส.', 'noun'),
#   ('ต่อไป', 'Adverbs'),
#   ('จึง', 'wordbeforeverb'),
#   ('เรียน', 'transitiveverb'),
#   ('มา', 'transitiveverb'),
#   ('เพื่อ', 'Prepositions'),
#   ('โปรดทราบ', 'noun')]]

# %%
with open('model.pkl','wb') as f:
    pickle.dump(crf,f)

# %%
with open('model.pkl', 'rb') as f:
    clf2 = pickle.load(f)

# %%
text = "วันนี้(วันที่ 5 สิงหาคม 2563) พล.ต.อ.วิสนุ ปราสาททองโอสถ ผู้ช่วย ผบ.ตร.พร้อมด้วย พล.ต.ท.ชินภัทร สารสิน ผบช.ปส.,พล.ต.ต.พรชัย. เจริญวงศ์ รอง ผบช.ปส.พล.ต.ต.วัชระ ทิพย์มงคล ผบก.ปส.3 บช.ปส.พล.ต.ต.บัณฑิต ทิศาภาค ผบก.สกส.บช.ปส. พล.ต.ต.สุรศักดิ์ สุขแสวง ผบก.ภ.จว.ประจวบคีรีขันธ์ นายกิตติพงศ์ สุขภาคกุล ปลัดจังหวัดประจวบคีรีขันธ์ และผู้แทนจากฝ่ายทหารและฝ่ายปกครองที่เกี่ยวข้อง ร่วมกันแถลงผลบูรณาการจับกุม-สกัดกั้นและยึดทรัพย์สินผู้ค้ายาเสพติดรายสำคัญในช่วงสถานการณ์โควิด-19 ยึดของกลางจำนวนมากภายใต้ยุทธการสยบไพรี 63/16 “ทลายขุมทรัพย์จับแก๊งยานรก” ปฏิบัติการ เด็ดปีกภมรวิจิตร โดยในวันนี้ ตำรวจปราบปรามยาเสพติดสนธิกำลังเข้าจับกุม ตรวจค้น ยึดทรัพย์ 
จากการสืบสวนติดตามกลุ่มนักค้ายาเสพติดชาวเขาเผ่าม้ง มีความสัมพันธ์แน่นแฟ้นเกี่ยวดอง ในลักษณะเครือญาติ โดยกลุ่มเครือข่ายนี้มีศักยภาพในการติดต่อสั่งซื้อยาเสพติดจากโรงงานผลิต ในสาธารณรัฐแห่งสหภาพ เมียนมา จัดหา ประสาน สั่งการลำเลียงยาเสพติด นำส่งเครือข่าย ซึ่งเป็นกลุ่มเครือญาติในพื้นที่ตอนใน มีการแบ่งหน้าที่ให้เครือญาติ และลูกหลาน ดำเนินการอย่างชัดเจน ครอบคลุม 3 พื้นที่ 3 ภาค ได้แก่ พื้นที่ต้นทาง ในพื้นที่ภาคเหนือซึ่งใกล้แหล่งผลิตและพื้นที่นำเข้า สะดวก ในการจัดหาเครือข่ายผู้ลำเลียงชาวเขาในพื้นที่เดียวกัน พื้นที่กลางทาง ในพื้นที่ กรุงเทพมหานคร ซึ่งเป็นจุดยุทธศาสตร์ใหม่ที่ใช้เป็นบ้านพัก สะดวกในการติดต่อเดินทางระหว่าง 2 พื้นที่ และอยู่ไม่ห่างจากจุดรับมอบยาเสพติดระหว่างกลุ่มผู้ลำเลียงทั้ง 2 ระยะ เพื่อส่งต่อไปยังพื้นที่ภาคใต้ต่อไป พื้นที่ปลายทาง ใช้เป็นแหล่งฟอกเงินและเป็นจุดกระแสเงินต้นทางในการโอนเงินค่ายาเสพติดและ ค่าจ้างลำเลียง โดยใช้ธุรกิจค้าเสื้อผ้า และร้านจำหน่ายสินค้าที่ระลึกชาวเขา บังหน้า โดยไม่ได้ต้องการหวังผลกำไรเป็นหลัก กลุ่มเครือข่ายนี้ใช้กระบวนการฟอกเงินโดยให้เครือญาติ ลูกหลาน เปิดบัญชีธนาคารและทำธุรกรรมทางการเงิน รวมทั้งแปรสภาพเงินดังกล่าวไปเป็นอสังหาริมทรัพย์และโอนกรรมสิทธิ์ให้เป็น ผู้ถือครองทั้งที่บุคคลเหล่านั้นมีการประกอบสัมมาชีพ ที่ไม่สอดคล้องกับรายได้และทรัพย์สิน ทั้งนี้ก็เพื่อป้องกันการตรวจสอบ และทำให้เกิดความซับซ้อนในการตรวจสอบจากเจ้าหน้าที่รัฐ สำหรับปฏิบัติการวันนี้ ตำรวจกระจายกำลังลงพื้นที่ 4 จังหวัด 30 เป้าหมาย คือจังหวัด เชียงใหม่ 22 เป้าหมาย, เชียงราย 1 เป้าหมาย, กรุงเทพ 1 เป้าหมาย และประจวบคีรีขันธ์ อีก 6 เป้าหมาย พบอีกว่าเครือข่าย ของนายสว่างมีทรัพย์สินจำนวนมาก โดยทรัพย์สินทั้งหมด มีการแบ่งชื่อผู้ครอบครอง เป็นเครือญาติ ของนายสว่างทั้งหมด"
#_tokenizer = Tokenizer(custom_dict=trie, engine='newmm')
word_cut=_tokenizer.word_tokenize(text)
list_word=pos_tag(word_cut,engine='perceptron')
X_test = extract_features([(data,list_word[i][1]) for i,data in enumerate(word_cut)])

# %%
clf2.predict_single(X_test)
